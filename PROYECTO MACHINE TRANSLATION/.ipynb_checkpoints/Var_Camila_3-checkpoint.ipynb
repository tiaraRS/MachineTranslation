# %%
from fit_model_ import *

# %%
def define_encdec_model(src_vocab,tar_vocab,src_timesteps,tar_timesteps, n_units, g_units,function="softmax"):
    """
    Build and train an encoder-decoder model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """

  
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length = src_timesteps,mask_zero=True))
    model.add(Bidirectional(GRU(g_units)))
    model.add(RepeatVector(tar_timesteps))
    model.add(Bidirectional(GRU(g_units,return_sequences=True)))
    model.add(TimeDistributed(Dense(tar_vocab,activation=function)))
    #model.add(t_d)
    
    
   
    
    return model

# %%
ds_filename, train_ds_fn, test_ds_fn = 'dataset/english-spanish-both-10000.txt', 'dataset/english-spanish-train-10000.txt','dataset/english-spanish-test-10000.txt'
units = 32
g_units = 64
learning_rate = 0.001
loss_func='sparse_categorical_crossentropy'
epochs=64
batch_size=64
model_save_file_name='Models/cp_model_3_1.h5'
history_save_file_name="cp_history_3_1.npy"

dataset,train,test=load_data(ds_filename, train_ds_fn, test_ds_fn)

eng_tokenizer,eng_vocab_size,eng_max_sentence_length = prepare_tokenizer(dataset,0)
spa_tokenizer,spa_vocab_size,spa_max_sentence_length = prepare_tokenizer(dataset,1)
print(eng_vocab_size,spa_vocab_size,eng_max_sentence_length,spa_max_sentence_length)

trainX, trainY =  preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, train, one_hot=False)
testX, testY = preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, test, one_hot=False)
print(trainX.shape, trainY.shape, testX.shape, testY.shape)

model3_1 = define_encdec_model(eng_vocab_size, spa_vocab_size, eng_max_sentence_length, spa_max_sentence_length, units,g_units, "softmax")
create_model(model3_1,loss_func,learning_rate)
plot_model(model3_1, to_file='model_images/cp_model_3_1_m.png', show_shapes=True)
train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model3_1, model_save_file_name,history_save_file_name)
graph_loss_vs_epochs(model3_1.history, 'loss_vs_epochs_images/cp_model_3_1_m.png', 'Model 3 var 1')
# Out:
# 2272 4510 5 8
# (8000, 5) (8000, 8) (2000, 5) (2000, 8)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 32)             72704
#
#  bidirectional (Bidirectiona  (None, 128)              37632
#  l)
#
#  repeat_vector (RepeatVector  (None, 8, 128)           0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 8, 128)           74496
#  nal)
#
#  time_distributed (TimeDistr  (None, 8, 4510)          581790
#  ibuted)
#
# =================================================================
# Total params: 766,622
# Trainable params: 766,622
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 2.64935, saving model to Models\cp_model_3_1.h5
# 125/125 - 17s - loss: 4.0242 - acc: 0.6340 - val_loss: 2.6494 - val_acc: 0.6417 - 17s/epoch - 140ms/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 2.64935 to 2.58925, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 2.5465 - acc: 0.6447 - val_loss: 2.5893 - val_acc: 0.6481 - 9s/epoch - 73ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 2.58925 to 2.57441, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 2.4814 - acc: 0.6494 - val_loss: 2.5744 - val_acc: 0.6524 - 9s/epoch - 72ms/step
# Epoch 4/64
#
# Epoch 4: val_loss improved from 2.57441 to 2.56387, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.4408 - acc: 0.6514 - val_loss: 2.5639 - val_acc: 0.6509 - 10s/epoch - 82ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 2.56387 to 2.55173, saving model to Models\cp_model_3_1.h5
# 125/125 - 11s - loss: 2.4086 - acc: 0.6546 - val_loss: 2.5517 - val_acc: 0.6545 - 11s/epoch - 84ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 2.55173 to 2.54562, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.3726 - acc: 0.6581 - val_loss: 2.5456 - val_acc: 0.6588 - 10s/epoch - 81ms/step
# Epoch 7/64
#
# Epoch 7: val_loss improved from 2.54562 to 2.53179, saving model to Models\cp_model_3_1.h5
# 125/125 - 11s - loss: 2.3390 - acc: 0.6601 - val_loss: 2.5318 - val_acc: 0.6603 - 11s/epoch - 86ms/step
# Epoch 8/64
#
# Epoch 8: val_loss improved from 2.53179 to 2.51774, saving model to Models\cp_model_3_1.h5
# 125/125 - 11s - loss: 2.3025 - acc: 0.6615 - val_loss: 2.5177 - val_acc: 0.6621 - 11s/epoch - 85ms/step
# Epoch 9/64
#
# Epoch 9: val_loss improved from 2.51774 to 2.48746, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.2626 - acc: 0.6642 - val_loss: 2.4875 - val_acc: 0.6628 - 10s/epoch - 82ms/step
# Epoch 10/64
#
# Epoch 10: val_loss improved from 2.48746 to 2.46261, saving model to Models\cp_model_3_1.h5
# 125/125 - 11s - loss: 2.2161 - acc: 0.6676 - val_loss: 2.4626 - val_acc: 0.6676 - 11s/epoch - 86ms/step
# Epoch 11/64
#
# Epoch 11: val_loss improved from 2.46261 to 2.43567, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.1616 - acc: 0.6731 - val_loss: 2.4357 - val_acc: 0.6709 - 10s/epoch - 77ms/step
# Epoch 12/64
#
# Epoch 12: val_loss improved from 2.43567 to 2.40881, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.1127 - acc: 0.6771 - val_loss: 2.4088 - val_acc: 0.6734 - 10s/epoch - 80ms/step
# Epoch 13/64
#
# Epoch 13: val_loss improved from 2.40881 to 2.38086, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.0666 - acc: 0.6803 - val_loss: 2.3809 - val_acc: 0.6777 - 10s/epoch - 83ms/step
# Epoch 14/64
#
# Epoch 14: val_loss improved from 2.38086 to 2.36478, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 2.0208 - acc: 0.6837 - val_loss: 2.3648 - val_acc: 0.6769 - 10s/epoch - 80ms/step
# Epoch 15/64
#
# Epoch 15: val_loss improved from 2.36478 to 2.34147, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.9770 - acc: 0.6876 - val_loss: 2.3415 - val_acc: 0.6817 - 10s/epoch - 82ms/step
# Epoch 16/64
#
# Epoch 16: val_loss improved from 2.34147 to 2.32914, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.9327 - acc: 0.6910 - val_loss: 2.3291 - val_acc: 0.6811 - 10s/epoch - 80ms/step
# Epoch 17/64
#
# Epoch 17: val_loss improved from 2.32914 to 2.30309, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.8896 - acc: 0.6938 - val_loss: 2.3031 - val_acc: 0.6856 - 10s/epoch - 77ms/step
# Epoch 18/64
#
# Epoch 18: val_loss improved from 2.30309 to 2.29075, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.8457 - acc: 0.6979 - val_loss: 2.2908 - val_acc: 0.6875 - 10s/epoch - 76ms/step
# Epoch 19/64
#
# Epoch 19: val_loss improved from 2.29075 to 2.27332, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.8050 - acc: 0.7017 - val_loss: 2.2733 - val_acc: 0.6903 - 10s/epoch - 76ms/step
# Epoch 20/64
#
# Epoch 20: val_loss improved from 2.27332 to 2.25547, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.7667 - acc: 0.7040 - val_loss: 2.2555 - val_acc: 0.6916 - 10s/epoch - 78ms/step
# Epoch 21/64
#
# Epoch 21: val_loss improved from 2.25547 to 2.24442, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.7289 - acc: 0.7078 - val_loss: 2.2444 - val_acc: 0.6927 - 10s/epoch - 80ms/step
# Epoch 22/64
#
# Epoch 22: val_loss improved from 2.24442 to 2.22991, saving model to Models\cp_model_3_1.h5
# 125/125 - 11s - loss: 1.6916 - acc: 0.7100 - val_loss: 2.2299 - val_acc: 0.6940 - 11s/epoch - 84ms/step
# Epoch 23/64
#
# Epoch 23: val_loss improved from 2.22991 to 2.21959, saving model to Models\cp_model_3_1.h5
# 125/125 - 11s - loss: 1.6573 - acc: 0.7133 - val_loss: 2.2196 - val_acc: 0.6961 - 11s/epoch - 90ms/step
# Epoch 24/64
#
# Epoch 24: val_loss improved from 2.21959 to 2.20812, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.6257 - acc: 0.7146 - val_loss: 2.2081 - val_acc: 0.6982 - 10s/epoch - 79ms/step
# Epoch 25/64
#
# Epoch 25: val_loss improved from 2.20812 to 2.19750, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.5929 - acc: 0.7169 - val_loss: 2.1975 - val_acc: 0.6995 - 10s/epoch - 79ms/step
# Epoch 26/64
#
# Epoch 26: val_loss improved from 2.19750 to 2.19230, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.5611 - acc: 0.7198 - val_loss: 2.1923 - val_acc: 0.6989 - 10s/epoch - 81ms/step
# Epoch 27/64
#
# Epoch 27: val_loss improved from 2.19230 to 2.17989, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.5305 - acc: 0.7228 - val_loss: 2.1799 - val_acc: 0.7004 - 10s/epoch - 76ms/step
# Epoch 28/64
#
# Epoch 28: val_loss improved from 2.17989 to 2.16857, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.5016 - acc: 0.7248 - val_loss: 2.1686 - val_acc: 0.7035 - 10s/epoch - 83ms/step
# Epoch 29/64
#
# Epoch 29: val_loss improved from 2.16857 to 2.16264, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.4717 - acc: 0.7267 - val_loss: 2.1626 - val_acc: 0.7032 - 10s/epoch - 77ms/step
# Epoch 30/64
#
# Epoch 30: val_loss improved from 2.16264 to 2.15294, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.4430 - acc: 0.7297 - val_loss: 2.1529 - val_acc: 0.7054 - 10s/epoch - 82ms/step
# Epoch 31/64
#
# Epoch 31: val_loss improved from 2.15294 to 2.14588, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 1.4142 - acc: 0.7320 - val_loss: 2.1459 - val_acc: 0.7057 - 10s/epoch - 79ms/step
# Epoch 32/64
#
# Epoch 32: val_loss did not improve from 2.14588
# 125/125 - 9s - loss: 1.3862 - acc: 0.7345 - val_loss: 2.1463 - val_acc: 0.7057 - 9s/epoch - 74ms/step
# Epoch 33/64
# Epoch 33: val_loss improved from 2.14588 to 2.13727, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.3576 - acc: 0.7379 - val_loss: 2.1373 - val_acc: 0.7080 - 9s/epoch - 75ms/step
# Epoch 34/64
#
# Epoch 34: val_loss improved from 2.13727 to 2.12476, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.3296 - acc: 0.7408 - val_loss: 2.1248 - val_acc: 0.7079 - 9s/epoch - 74ms/step
# Epoch 35/64
#
# Epoch 35: val_loss improved from 2.12476 to 2.11749, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.3034 - acc: 0.7431 - val_loss: 2.1175 - val_acc: 0.7094 - 9s/epoch - 74ms/step
# Epoch 36/64
#
# Epoch 36: val_loss improved from 2.11749 to 2.11231, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.2743 - acc: 0.7465 - val_loss: 2.1123 - val_acc: 0.7096 - 9s/epoch - 75ms/step
# Epoch 37/64
#
# Epoch 37: val_loss improved from 2.11231 to 2.10645, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.2465 - acc: 0.7488 - val_loss: 2.1065 - val_acc: 0.7109 - 9s/epoch - 73ms/step
# Epoch 38/64
#
# Epoch 38: val_loss improved from 2.10645 to 2.10019, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.2175 - acc: 0.7521 - val_loss: 2.1002 - val_acc: 0.7113 - 9s/epoch - 75ms/step
# Epoch 39/64
#
# Epoch 39: val_loss improved from 2.10019 to 2.09289, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.1908 - acc: 0.7549 - val_loss: 2.0929 - val_acc: 0.7133 - 9s/epoch - 74ms/step
# Epoch 40/64
#
# Epoch 40: val_loss improved from 2.09289 to 2.09182, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.1625 - acc: 0.7579 - val_loss: 2.0918 - val_acc: 0.7136 - 9s/epoch - 75ms/step
# Epoch 41/64
#
# Epoch 41: val_loss improved from 2.09182 to 2.08336, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.1354 - acc: 0.7608 - val_loss: 2.0834 - val_acc: 0.7138 - 9s/epoch - 75ms/step
# Epoch 42/64
#
# Epoch 42: val_loss improved from 2.08336 to 2.07323, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.1085 - acc: 0.7645 - val_loss: 2.0732 - val_acc: 0.7143 - 9s/epoch - 74ms/step
# Epoch 43/64
#
# Epoch 43: val_loss did not improve from 2.07323
# 125/125 - 9s - loss: 1.0817 - acc: 0.7686 - val_loss: 2.0788 - val_acc: 0.7127 - 9s/epoch - 75ms/step
# Epoch 44/64
#
# Epoch 44: val_loss improved from 2.07323 to 2.07033, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.0555 - acc: 0.7706 - val_loss: 2.0703 - val_acc: 0.7153 - 9s/epoch - 74ms/step
# Epoch 45/64
#
# Epoch 45: val_loss improved from 2.07033 to 2.06844, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.0287 - acc: 0.7750 - val_loss: 2.0684 - val_acc: 0.7153 - 9s/epoch - 75ms/step
# Epoch 46/64
#
# Epoch 46: val_loss improved from 2.06844 to 2.06665, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 1.0021 - acc: 0.7797 - val_loss: 2.0667 - val_acc: 0.7142 - 9s/epoch - 75ms/step
# Epoch 47/64
#
# Epoch 47: val_loss improved from 2.06665 to 2.06514, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 0.9783 - acc: 0.7820 - val_loss: 2.0651 - val_acc: 0.7149 - 9s/epoch - 75ms/step
# Epoch 48/64
#
# Epoch 48: val_loss improved from 2.06514 to 2.05935, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 0.9514 - acc: 0.7861 - val_loss: 2.0593 - val_acc: 0.7166 - 9s/epoch - 76ms/step
# Epoch 49/64
#
# Epoch 49: val_loss did not improve from 2.05935
# 125/125 - 9s - loss: 0.9277 - acc: 0.7908 - val_loss: 2.0617 - val_acc: 0.7164 - 9s/epoch - 73ms/step
# Epoch 50/64
#
# Epoch 50: val_loss improved from 2.05935 to 2.05667, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 0.9017 - acc: 0.7943 - val_loss: 2.0567 - val_acc: 0.7159 - 10s/epoch - 79ms/step
# Epoch 51/64
#
# Epoch 51: val_loss did not improve from 2.05667
# 125/125 - 9s - loss: 0.8797 - acc: 0.7987 - val_loss: 2.0579 - val_acc: 0.7166 - 9s/epoch - 74ms/step
# Epoch 52/64
#
# Epoch 52: val_loss improved from 2.05667 to 2.05006, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 0.8556 - acc: 0.8032 - val_loss: 2.0501 - val_acc: 0.7191 - 10s/epoch - 76ms/step
# Epoch 53/64
#
# Epoch 53: val_loss improved from 2.05006 to 2.04965, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 0.8325 - acc: 0.8077 - val_loss: 2.0497 - val_acc: 0.7184 - 10s/epoch - 76ms/step
# Epoch 54/64
#
# Epoch 54: val_loss did not improve from 2.04965
# 125/125 - 9s - loss: 0.8114 - acc: 0.8106 - val_loss: 2.0502 - val_acc: 0.7191 - 9s/epoch - 75ms/step
# Epoch 55/64
#
# Epoch 55: val_loss improved from 2.04965 to 2.04280, saving model to Models\cp_model_3_1.h5
# 125/125 - 10s - loss: 0.7902 - acc: 0.8154 - val_loss: 2.0428 - val_acc: 0.7199 - 10s/epoch - 76ms/step
# Epoch 56/64
#
# Epoch 56: val_loss did not improve from 2.04280
# 125/125 - 9s - loss: 0.7694 - acc: 0.8185 - val_loss: 2.0483 - val_acc: 0.7178 - 9s/epoch - 75ms/step
# Epoch 57/64
#
# Epoch 57: val_loss did not improve from 2.04280
# 125/125 - 10s - loss: 0.7496 - acc: 0.8220 - val_loss: 2.0457 - val_acc: 0.7199 - 10s/epoch - 77ms/step
# Epoch 58/64
#
# Epoch 58: val_loss did not improve from 2.04280
# 125/125 - 10s - loss: 0.7314 - acc: 0.8257 - val_loss: 2.0475 - val_acc: 0.7189 - 10s/epoch - 77ms/step
# Epoch 59/64
#
# Epoch 59: val_loss did not improve from 2.04280
# 125/125 - 9s - loss: 0.7113 - acc: 0.8291 - val_loss: 2.0449 - val_acc: 0.7213 - 9s/epoch - 75ms/step
# Epoch 60/64
#
# Epoch 60: val_loss did not improve from 2.04280
# 125/125 - 10s - loss: 0.6948 - acc: 0.8334 - val_loss: 2.0487 - val_acc: 0.7190 - 10s/epoch - 77ms/step
# Epoch 61/64
#
# Epoch 61: val_loss improved from 2.04280 to 2.04069, saving model to Models\cp_model_3_1.h5
# 125/125 - 9s - loss: 0.6775 - acc: 0.8353 - val_loss: 2.0407 - val_acc: 0.7228 - 9s/epoch - 76ms/step
# Epoch 62/64
#
# Epoch 62: val_loss did not improve from 2.04069
# 125/125 - 10s - loss: 0.6619 - acc: 0.8393 - val_loss: 2.0455 - val_acc: 0.7211 - 10s/epoch - 77ms/step
# Epoch 63/64
#
# Epoch 63: val_loss did not improve from 2.04069
# 125/125 - 10s - loss: 0.6470 - acc: 0.8420 - val_loss: 2.0469 - val_acc: 0.7214 - 10s/epoch - 77ms/step
# Epoch 64/64
#
# Epoch 64: val_loss did not improve from 2.04069
# 125/125 - 10s - loss: 0.6335 - acc: 0.8440 - val_loss: 2.0463 - val_acc: 0.7219 - 10s/epoch - 76ms/step

# %%
ds_filename, train_ds_fn, test_ds_fn = 'dataset/english-spanish-both-10000.txt', 'dataset/english-spanish-train-10000.txt','dataset/english-spanish-test-10000.txt'
units = 256
g_units = 128
learning_rate = 0.005
loss_func='sparse_categorical_crossentropy'
epochs=32
batch_size=64
model_save_file_name='Models/cp_model_3_2.h5'
history_save_file_name="cp_history_3_2.npy"

dataset,train,test=load_data(ds_filename, train_ds_fn, test_ds_fn)

eng_tokenizer,eng_vocab_size,eng_max_sentence_length = prepare_tokenizer(dataset,0)
spa_tokenizer,spa_vocab_size,spa_max_sentence_length = prepare_tokenizer(dataset,1)
print(eng_vocab_size,spa_vocab_size,eng_max_sentence_length,spa_max_sentence_length)

trainX, trainY =  preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, train, one_hot=False)
testX, testY = preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, test, one_hot=False)
print(trainX.shape, trainY.shape, testX.shape, testY.shape)

model3_2 = define_encdec_model(eng_vocab_size, spa_vocab_size, eng_max_sentence_length, spa_max_sentence_length, units,g_units,"softmax")
create_model(model3_2,loss_func,learning_rate)
plot_model(model3_2, to_file='model_images/cp_model_3_2_m.png', show_shapes=True)
train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model3_2, model_save_file_name,history_save_file_name)
graph_loss_vs_epochs(model3_2.history, 'loss_vs_epochs_images/cp_model_3_2_le.png', 'Model 3 var 2')
# Out:
# 2272 4510 5 8
# (8000, 5) (8000, 8) (2000, 5) (2000, 8)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 5, 256)            581632
#
#  bidirectional_4 (Bidirectio  (None, 256)              296448
#  nal)
#
#  repeat_vector_2 (RepeatVect  (None, 8, 256)           0
#  or)
#
#  bidirectional_5 (Bidirectio  (None, 8, 256)           296448
#  nal)
#
#  time_distributed_2 (TimeDis  (None, 8, 4510)          1159070
#  tributed)
#
# =================================================================
# Total params: 2,333,598
# Trainable params: 2,333,598
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/32
#
# Epoch 1: val_loss improved from inf to 2.68489, saving model to Models\cp_model_3_2.h5
# 125/125 - 20s - loss: 3.1265 - acc: 0.6401 - val_loss: 2.6849 - val_acc: 0.6524 - 20s/epoch - 163ms/step
# Epoch 2/32
#
# Epoch 2: val_loss improved from 2.68489 to 2.63423, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 2.5711 - acc: 0.6559 - val_loss: 2.6342 - val_acc: 0.6675 - 13s/epoch - 104ms/step
# Epoch 3/32
#
# Epoch 3: val_loss improved from 2.63423 to 2.49075, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 2.3726 - acc: 0.6737 - val_loss: 2.4907 - val_acc: 0.6784 - 13s/epoch - 103ms/step
# Epoch 4/32
#
# Epoch 4: val_loss improved from 2.49075 to 2.32586, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 2.1392 - acc: 0.6917 - val_loss: 2.3259 - val_acc: 0.6924 - 13s/epoch - 102ms/step
# Epoch 5/32
#
# Epoch 5: val_loss improved from 2.32586 to 2.22115, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 1.8933 - acc: 0.7093 - val_loss: 2.2212 - val_acc: 0.7024 - 13s/epoch - 103ms/step
# Epoch 6/32
#
# Epoch 6: val_loss improved from 2.22115 to 2.12044, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 1.6654 - acc: 0.7247 - val_loss: 2.1204 - val_acc: 0.7090 - 13s/epoch - 102ms/step
# Epoch 7/32
#
# Epoch 7: val_loss improved from 2.12044 to 2.07194, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 1.4524 - acc: 0.7395 - val_loss: 2.0719 - val_acc: 0.7141 - 13s/epoch - 101ms/step
# Epoch 8/32
#
# Epoch 8: val_loss improved from 2.07194 to 2.03318, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 1.2725 - acc: 0.7533 - val_loss: 2.0332 - val_acc: 0.7216 - 13s/epoch - 103ms/step
# Epoch 9/32
#
# Epoch 9: val_loss improved from 2.03318 to 2.00950, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 1.1277 - acc: 0.7651 - val_loss: 2.0095 - val_acc: 0.7151 - 13s/epoch - 102ms/step
# Epoch 10/32
#
# Epoch 10: val_loss improved from 2.00950 to 1.94949, saving model to Models\cp_model_3_2.h5
# 125/125 - 14s - loss: 0.9615 - acc: 0.7822 - val_loss: 1.9495 - val_acc: 0.7272 - 14s/epoch - 110ms/step
# Epoch 11/32
#
# Epoch 11: val_loss improved from 1.94949 to 1.94859, saving model to Models\cp_model_3_2.h5
# 125/125 - 15s - loss: 0.8300 - acc: 0.8005 - val_loss: 1.9486 - val_acc: 0.7213 - 15s/epoch - 120ms/step
# Epoch 12/32
#
# Epoch 12: val_loss improved from 1.94859 to 1.94413, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 0.7221 - acc: 0.8193 - val_loss: 1.9441 - val_acc: 0.7274 - 13s/epoch - 108ms/step
# Epoch 13/32
#
# Epoch 13: val_loss did not improve from 1.94413
# 125/125 - 13s - loss: 0.6414 - acc: 0.8339 - val_loss: 1.9556 - val_acc: 0.7238 - 13s/epoch - 107ms/step
# Epoch 14/32
#
# Epoch 14: val_loss improved from 1.94413 to 1.94252, saving model to Models\cp_model_3_2.h5
# 125/125 - 13s - loss: 0.5809 - acc: 0.8451 - val_loss: 1.9425 - val_acc: 0.7311 - 13s/epoch - 106ms/step
# Epoch 15/32
#
# Epoch 15: val_loss did not improve from 1.94252
# 125/125 - 13s - loss: 0.5268 - acc: 0.8566 - val_loss: 1.9615 - val_acc: 0.7300 - 13s/epoch - 108ms/step
# Epoch 16/32
#
# Epoch 16: val_loss did not improve from 1.94252
# 125/125 - 13s - loss: 0.4888 - acc: 0.8646 - val_loss: 1.9773 - val_acc: 0.7299 - 13s/epoch - 107ms/step
# Epoch 17/32
#
# Epoch 17: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.4616 - acc: 0.8700 - val_loss: 1.9983 - val_acc: 0.7299 - 14s/epoch - 110ms/step
# Epoch 18/32
#
# Epoch 18: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.4357 - acc: 0.8754 - val_loss: 2.0117 - val_acc: 0.7309 - 14s/epoch - 110ms/step
# Epoch 19/32
#
# Epoch 19: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.4085 - acc: 0.8804 - val_loss: 2.0305 - val_acc: 0.7269 - 14s/epoch - 113ms/step
# Epoch 20/32
#
# Epoch 20: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3893 - acc: 0.8847 - val_loss: 2.0528 - val_acc: 0.7286 - 14s/epoch - 115ms/step
# Epoch 21/32
#
# Epoch 21: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3796 - acc: 0.8860 - val_loss: 2.0541 - val_acc: 0.7296 - 14s/epoch - 115ms/step
# Epoch 22/32
#
# Epoch 22: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3691 - acc: 0.8875 - val_loss: 2.0773 - val_acc: 0.7302 - 14s/epoch - 115ms/step
# Epoch 23/32
#
# Epoch 23: val_loss did not improve from 1.94252
# 125/125 - 15s - loss: 0.3593 - acc: 0.8882 - val_loss: 2.0901 - val_acc: 0.7301 - 15s/epoch - 119ms/step
# Epoch 24/32
#
# Epoch 24: val_loss did not improve from 1.94252
# 125/125 - 15s - loss: 0.3526 - acc: 0.8907 - val_loss: 2.0962 - val_acc: 0.7294 - 15s/epoch - 121ms/step
# Epoch 25/32
#
# Epoch 25: val_loss did not improve from 1.94252
# 125/125 - 15s - loss: 0.3521 - acc: 0.8899 - val_loss: 2.1151 - val_acc: 0.7276 - 15s/epoch - 121ms/step
# Epoch 26/32
#
# Epoch 26: val_loss did not improve from 1.94252
# 125/125 - 15s - loss: 0.3481 - acc: 0.8907 - val_loss: 2.1335 - val_acc: 0.7324 - 15s/epoch - 118ms/step
# Epoch 27/32
#
# Epoch 27: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3391 - acc: 0.8921 - val_loss: 2.1407 - val_acc: 0.7290 - 14s/epoch - 113ms/step
# Epoch 28/32
#
# Epoch 28: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3336 - acc: 0.8927 - val_loss: 2.1645 - val_acc: 0.7260 - 14s/epoch - 112ms/step
# Epoch 29/32
#
# Epoch 29: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3301 - acc: 0.8938 - val_loss: 2.1658 - val_acc: 0.7314 - 14s/epoch - 113ms/step
# Epoch 30/32
#
# Epoch 30: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3252 - acc: 0.8947 - val_loss: 2.1581 - val_acc: 0.7306 - 14s/epoch - 111ms/step
# Epoch 31/32
#
# Epoch 31: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3216 - acc: 0.8952 - val_loss: 2.1752 - val_acc: 0.7293 - 14s/epoch - 113ms/step
# Epoch 32/32
#
# Epoch 32: val_loss did not improve from 1.94252
# 125/125 - 14s - loss: 0.3148 - acc: 0.8964 - val_loss: 2.1966 - val_acc: 0.7293 - 14s/epoch - 112ms/step

# %%
ds_filename, train_ds_fn, test_ds_fn = 'dataset/english-spanish-both-10000.txt', 'dataset/english-spanish-train-10000.txt','dataset/english-spanish-test-10000.txt'
units = 128
g_units=32
learning_rate = 0.005
loss_func='sparse_categorical_crossentropy'
epochs=64
batch_size=128
model_save_file_name='Models/cp_model_3_3.h5'
history_save_file_name="cp_history_3_3.npy"

dataset,train,test=load_data(ds_filename, train_ds_fn, test_ds_fn)

eng_tokenizer,eng_vocab_size,eng_max_sentence_length = prepare_tokenizer(dataset,0)
spa_tokenizer,spa_vocab_size,spa_max_sentence_length = prepare_tokenizer(dataset,1)
print(eng_vocab_size,spa_vocab_size,eng_max_sentence_length,spa_max_sentence_length)

trainX, trainY =  preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, train, one_hot=False)
testX, testY = preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, test, one_hot=False)
print(trainX.shape, trainY.shape, testX.shape, testY.shape)

model3_3 = define_encdec_model(eng_vocab_size, spa_vocab_size, eng_max_sentence_length, spa_max_sentence_length, units,g_units,"sigmoid")
create_model(model3_3,loss_func,learning_rate)
plot_model(model3_3, to_file='model_images/cp_model_3_3_m.png', show_shapes=True)
train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model3_3, model_save_file_name,history_save_file_name)
graph_loss_vs_epochs(model3_3.history, 'loss_vs_epochs_images/cp_model_3_3_le.png', 'Model 3 var 3')
# Out:
# 2272 4510 5 8
# (8000, 5) (8000, 8) (2000, 5) (2000, 8)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 5, 128)            290816
#
#  bidirectional_6 (Bidirectio  (None, 64)               31104
#  nal)
#
#  repeat_vector_3 (RepeatVect  (None, 8, 64)            0
#  or)
#
#  bidirectional_7 (Bidirectio  (None, 8, 64)            18816
#  nal)
#
#  time_distributed_3 (TimeDis  (None, 8, 4510)          293150
#  tributed)
#
# =================================================================
# Total params: 633,886
# Trainable params: 633,886
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 4.24166, saving model to Models\cp_model_3_3.h5
# 63/63 - 18s - loss: 5.6251 - acc: 0.6309 - val_loss: 4.2417 - val_acc: 0.6391 - 18s/epoch - 283ms/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 4.24166 to 2.76492, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 3.3424 - acc: 0.6392 - val_loss: 2.7649 - val_acc: 0.6417 - 9s/epoch - 140ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 2.76492 to 2.65079, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 2.6276 - acc: 0.6409 - val_loss: 2.6508 - val_acc: 0.6394 - 9s/epoch - 141ms/step
# Epoch 4/64
#
# Epoch 4: val_loss improved from 2.65079 to 2.60788, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.5337 - acc: 0.6409 - val_loss: 2.6079 - val_acc: 0.6409 - 8s/epoch - 126ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 2.60788 to 2.57885, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.4713 - acc: 0.6475 - val_loss: 2.5788 - val_acc: 0.6503 - 8s/epoch - 126ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 2.57885 to 2.57822, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.4282 - acc: 0.6512 - val_loss: 2.5782 - val_acc: 0.6493 - 8s/epoch - 130ms/step
# Epoch 7/64
#
# Epoch 7: val_loss improved from 2.57822 to 2.56088, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 2.3967 - acc: 0.6522 - val_loss: 2.5609 - val_acc: 0.6497 - 9s/epoch - 142ms/step
# Epoch 8/64
#
# Epoch 8: val_loss improved from 2.56088 to 2.54473, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 2.3675 - acc: 0.6528 - val_loss: 2.5447 - val_acc: 0.6503 - 9s/epoch - 140ms/step
# Epoch 9/64
#
# Epoch 9: val_loss improved from 2.54473 to 2.53844, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.3343 - acc: 0.6554 - val_loss: 2.5384 - val_acc: 0.6490 - 8s/epoch - 127ms/step
# Epoch 10/64
#
# Epoch 10: val_loss improved from 2.53844 to 2.51191, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.2972 - acc: 0.6572 - val_loss: 2.5119 - val_acc: 0.6528 - 8s/epoch - 128ms/step
# Epoch 11/64
#
# Epoch 11: val_loss improved from 2.51191 to 2.49640, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.2561 - acc: 0.6598 - val_loss: 2.4964 - val_acc: 0.6602 - 8s/epoch - 123ms/step
# Epoch 12/64
#
# Epoch 12: val_loss improved from 2.49640 to 2.46958, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.2123 - acc: 0.6681 - val_loss: 2.4696 - val_acc: 0.6654 - 8s/epoch - 125ms/step
# Epoch 13/64
#
# Epoch 13: val_loss improved from 2.46958 to 2.44107, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.1619 - acc: 0.6735 - val_loss: 2.4411 - val_acc: 0.6662 - 8s/epoch - 127ms/step
# Epoch 14/64
#
# Epoch 14: val_loss improved from 2.44107 to 2.41322, saving model to Models\cp_model_3_3.h5
# 63/63 - 10s - loss: 2.1086 - acc: 0.6773 - val_loss: 2.4132 - val_acc: 0.6671 - 10s/epoch - 163ms/step
# Epoch 15/64
#
# Epoch 15: val_loss improved from 2.41322 to 2.38838, saving model to Models\cp_model_3_3.h5
# 63/63 - 10s - loss: 2.0536 - acc: 0.6817 - val_loss: 2.3884 - val_acc: 0.6700 - 10s/epoch - 152ms/step
# Epoch 16/64
#
# Epoch 16: val_loss improved from 2.38838 to 2.35837, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 2.0033 - acc: 0.6848 - val_loss: 2.3584 - val_acc: 0.6743 - 8s/epoch - 130ms/step
# Epoch 17/64
#
# Epoch 17: val_loss improved from 2.35837 to 2.34317, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 1.9504 - acc: 0.6894 - val_loss: 2.3432 - val_acc: 0.6761 - 8s/epoch - 135ms/step
# Epoch 18/64
#
# Epoch 18: val_loss improved from 2.34317 to 2.31710, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.8985 - acc: 0.6949 - val_loss: 2.3171 - val_acc: 0.6787 - 9s/epoch - 142ms/step
# Epoch 19/64
#
# Epoch 19: val_loss improved from 2.31710 to 2.28720, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.8496 - acc: 0.6986 - val_loss: 2.2872 - val_acc: 0.6841 - 9s/epoch - 136ms/step
# Epoch 20/64
#
# Epoch 20: val_loss improved from 2.28720 to 2.26073, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.8019 - acc: 0.7020 - val_loss: 2.2607 - val_acc: 0.6856 - 9s/epoch - 138ms/step
# Epoch 21/64
#
# Epoch 21: val_loss improved from 2.26073 to 2.24855, saving model to Models\cp_model_3_3.h5
# 63/63 - 10s - loss: 1.7515 - acc: 0.7077 - val_loss: 2.2485 - val_acc: 0.6869 - 10s/epoch - 166ms/step
# Epoch 22/64
#
# Epoch 22: val_loss improved from 2.24855 to 2.23021, saving model to Models\cp_model_3_3.h5
# 63/63 - 10s - loss: 1.7033 - acc: 0.7119 - val_loss: 2.2302 - val_acc: 0.6883 - 10s/epoch - 152ms/step
# Epoch 23/64
#
# Epoch 23: val_loss improved from 2.23021 to 2.21242, saving model to Models\cp_model_3_3.h5
# 63/63 - 10s - loss: 1.6550 - acc: 0.7171 - val_loss: 2.2124 - val_acc: 0.6892 - 10s/epoch - 157ms/step
# Epoch 24/64
#
# Epoch 24: val_loss improved from 2.21242 to 2.19373, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 1.6096 - acc: 0.7208 - val_loss: 2.1937 - val_acc: 0.6894 - 8s/epoch - 131ms/step
# Epoch 25/64
#
# Epoch 25: val_loss improved from 2.19373 to 2.17328, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.5613 - acc: 0.7258 - val_loss: 2.1733 - val_acc: 0.6961 - 9s/epoch - 141ms/step
# Epoch 26/64
#
# Epoch 26: val_loss improved from 2.17328 to 2.16567, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.5182 - acc: 0.7286 - val_loss: 2.1657 - val_acc: 0.6941 - 9s/epoch - 148ms/step
# Epoch 27/64
#
# Epoch 27: val_loss improved from 2.16567 to 2.15444, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.4791 - acc: 0.7320 - val_loss: 2.1544 - val_acc: 0.6957 - 9s/epoch - 142ms/step
# Epoch 28/64
#
# Epoch 28: val_loss improved from 2.15444 to 2.14395, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.4392 - acc: 0.7362 - val_loss: 2.1440 - val_acc: 0.6969 - 9s/epoch - 135ms/step
# Epoch 29/64
#
# Epoch 29: val_loss did not improve from 2.14395
# 63/63 - 9s - loss: 1.3994 - acc: 0.7386 - val_loss: 2.1496 - val_acc: 0.6956 - 9s/epoch - 140ms/step
# Epoch 30/64
#
# Epoch 30: val_loss improved from 2.14395 to 2.13612, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.3598 - acc: 0.7432 - val_loss: 2.1361 - val_acc: 0.6965 - 9s/epoch - 143ms/step
# Epoch 31/64
#
# Epoch 31: val_loss improved from 2.13612 to 2.12622, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.3221 - acc: 0.7467 - val_loss: 2.1262 - val_acc: 0.6973 - 9s/epoch - 143ms/step
# Epoch 32/64
#
# Epoch 32: val_loss improved from 2.12622 to 2.12550, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 1.2819 - acc: 0.7506 - val_loss: 2.1255 - val_acc: 0.7008 - 8s/epoch - 134ms/step
# Epoch 33/64
#
# Epoch 33: val_loss improved from 2.12550 to 2.11602, saving model to Models\cp_model_3_3.h5
# 63/63 - 8s - loss: 1.2476 - acc: 0.7546 - val_loss: 2.1160 - val_acc: 0.7003 - 8s/epoch - 134ms/step
# Epoch 34/64
#
# Epoch 34: val_loss did not improve from 2.11602
# 63/63 - 10s - loss: 1.2168 - acc: 0.7576 - val_loss: 2.1160 - val_acc: 0.7012 - 10s/epoch - 154ms/step
# Epoch 35/64
#
# Epoch 35: val_loss did not improve from 2.11602
# 63/63 - 9s - loss: 1.1839 - acc: 0.7612 - val_loss: 2.1187 - val_acc: 0.6994 - 9s/epoch - 149ms/step
# Epoch 36/64
#
# Epoch 36: val_loss did not improve from 2.11602
# 63/63 - 9s - loss: 1.1527 - acc: 0.7654 - val_loss: 2.1209 - val_acc: 0.7012 - 9s/epoch - 136ms/step
# Epoch 37/64
#
# Epoch 37: val_loss did not improve from 2.11602
# 63/63 - 8s - loss: 1.1224 - acc: 0.7692 - val_loss: 2.1188 - val_acc: 0.7044 - 8s/epoch - 132ms/step
# Epoch 38/64
#
# Epoch 38: val_loss improved from 2.11602 to 2.10791, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.0974 - acc: 0.7713 - val_loss: 2.1079 - val_acc: 0.7036 - 9s/epoch - 141ms/step
# Epoch 39/64
#
# Epoch 39: val_loss improved from 2.10791 to 2.10388, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.0701 - acc: 0.7748 - val_loss: 2.1039 - val_acc: 0.7040 - 9s/epoch - 145ms/step
# Epoch 40/64
#
# Epoch 40: val_loss improved from 2.10388 to 2.10068, saving model to Models\cp_model_3_3.h5
# 63/63 - 9s - loss: 1.0392 - acc: 0.7789 - val_loss: 2.1007 - val_acc: 0.7077 - 9s/epoch - 138ms/step
# Epoch 41/64
#
# Epoch 41: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 1.0162 - acc: 0.7822 - val_loss: 2.1097 - val_acc: 0.7023 - 9s/epoch - 146ms/step
# Epoch 42/64
#
# Epoch 42: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.9920 - acc: 0.7857 - val_loss: 2.1044 - val_acc: 0.7057 - 9s/epoch - 141ms/step
# Epoch 43/64
#
# Epoch 43: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.9685 - acc: 0.7878 - val_loss: 2.1017 - val_acc: 0.7086 - 9s/epoch - 146ms/step
# Epoch 44/64
#
# Epoch 44: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.9446 - acc: 0.7923 - val_loss: 2.1022 - val_acc: 0.7049 - 9s/epoch - 146ms/step
# Epoch 45/64
#
# Epoch 45: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.9241 - acc: 0.7952 - val_loss: 2.1020 - val_acc: 0.7077 - 9s/epoch - 151ms/step
# Epoch 46/64
#
# Epoch 46: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.9013 - acc: 0.7986 - val_loss: 2.1052 - val_acc: 0.7066 - 9s/epoch - 137ms/step
# Epoch 47/64
#
# Epoch 47: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.8814 - acc: 0.8015 - val_loss: 2.1123 - val_acc: 0.7053 - 9s/epoch - 141ms/step
# Epoch 48/64
#
# Epoch 48: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.8623 - acc: 0.8046 - val_loss: 2.1092 - val_acc: 0.7083 - 9s/epoch - 137ms/step
# Epoch 49/64
#
# Epoch 49: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.8441 - acc: 0.8066 - val_loss: 2.1150 - val_acc: 0.7049 - 8s/epoch - 127ms/step
# Epoch 50/64
#
# Epoch 50: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.8273 - acc: 0.8096 - val_loss: 2.1137 - val_acc: 0.7082 - 8s/epoch - 130ms/step
# Epoch 51/64
#
# Epoch 51: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.8108 - acc: 0.8120 - val_loss: 2.1168 - val_acc: 0.7089 - 8s/epoch - 131ms/step
# Epoch 52/64
#
# Epoch 52: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.7952 - acc: 0.8154 - val_loss: 2.1310 - val_acc: 0.7057 - 8s/epoch - 134ms/step
# Epoch 53/64
#
# Epoch 53: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.7823 - acc: 0.8175 - val_loss: 2.1218 - val_acc: 0.7076 - 8s/epoch - 128ms/step
# Epoch 54/64
#
# Epoch 54: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.7690 - acc: 0.8195 - val_loss: 2.1230 - val_acc: 0.7086 - 8s/epoch - 132ms/step
# Epoch 55/64
#
# Epoch 55: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.7517 - acc: 0.8221 - val_loss: 2.1335 - val_acc: 0.7049 - 8s/epoch - 129ms/step
# Epoch 56/64
#
# Epoch 56: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.7350 - acc: 0.8241 - val_loss: 2.1433 - val_acc: 0.7038 - 8s/epoch - 133ms/step
# Epoch 57/64
#
# Epoch 57: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.7206 - acc: 0.8264 - val_loss: 2.1409 - val_acc: 0.7074 - 9s/epoch - 138ms/step
# Epoch 58/64
#
# Epoch 58: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.7102 - acc: 0.8296 - val_loss: 2.1493 - val_acc: 0.7050 - 8s/epoch - 135ms/step
# Epoch 59/64
#
# Epoch 59: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.6975 - acc: 0.8318 - val_loss: 2.1542 - val_acc: 0.7033 - 8s/epoch - 130ms/step
# Epoch 60/64
#
# Epoch 60: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.6846 - acc: 0.8336 - val_loss: 2.1610 - val_acc: 0.7040 - 8s/epoch - 127ms/step
# Epoch 61/64
#
# Epoch 61: val_loss did not improve from 2.10068
# 63/63 - 8s - loss: 0.6716 - acc: 0.8362 - val_loss: 2.1482 - val_acc: 0.7068 - 8s/epoch - 133ms/step
# Epoch 62/64
#
# Epoch 62: val_loss did not improve from 2.10068
# 63/63 - 9s - loss: 0.6616 - acc: 0.8386 - val_loss: 2.1548 - val_acc: 0.7061 - 9s/epoch - 143ms/step
# Epoch 63/64
#
# Epoch 63: val_loss did not improve from 2.10068
# 63/63 - 10s - loss: 0.6459 - acc: 0.8420 - val_loss: 2.1569 - val_acc: 0.7098 - 10s/epoch - 151ms/step
# Epoch 64/64
#
# Epoch 64: val_loss did not improve from 2.10068
# 63/63 - 11s - loss: 0.6382 - acc: 0.8427 - val_loss: 2.1645 - val_acc: 0.7084 - 11s/epoch - 168ms/step

# %%
hist1 = load_history("cp_history_3_1.npy")
hist2 = load_history("cp_history_3_2.npy")
hist3 = load_history("cp_history_3_3.npy")
for x in ['loss']:
    plt.plot(hist1[x],label="Historic 1")
    plt.plot(hist2[x],label="Historic 2")
    plt.plot(hist3[x],label="Historic 3")
plt.legend()
plt.xlabel("EPOCHS",fontsize=13)
plt.ylabel("LOSS",fontsize=13)
# Out:
# Text(0, 0.5, 'LOSS')
