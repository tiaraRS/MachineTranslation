# %%
from fit_model_ import *

# %% [markdown]
# ### Model 2 is a RNN with Embedding

# %%
 #eng_vocab_size, spa_vocab_size, eng_max_Sentence_length, spa_max_sen, units
def define_model_embedding(src_vocab, tar_vocab, src_timesteps, tar_timesteps,n_units,function="softmax"):
    """
    Build and train a RNN model using word embedding on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    #TODO: Implement
    learning_rate = 1e-3
    rnn = GRU(n_units)
    
    embedding = Embedding(src_vocab, n_units, input_length=src_timesteps,mask_zero=True) 
    logits = TimeDistributed(Dense(tar_vocab, activation=function))
    
    model = Sequential()
    #em can only be used in first layer --> Keras Documentation
    model.add(embedding)
    model.add(rnn)
    model.add(RepeatVector(tar_timesteps))
    model.add(GRU(n_units,return_sequences=True))
    model.add(logits)
    return model

# %% [markdown]
# ### Variante 1

# %%
ds_filename, train_ds_fn, test_ds_fn = 'dataset/english-spanish-both-10000.txt', 'dataset/english-spanish-train-10000.txt','dataset/english-spanish-test-10000.txt'
units = 256
learning_rate = 0.001
loss_func='sparse_categorical_crossentropy'
epochs=32
batch_size=64
model_save_file_name='Models/cp_model_1_1.h5'
history_save_file_name="cp_history_1_1.npy"

dataset,train,test=load_data(ds_filename, train_ds_fn, test_ds_fn)

eng_tokenizer,eng_vocab_size,eng_max_sentence_length = prepare_tokenizer(dataset,0)
spa_tokenizer,spa_vocab_size,spa_max_sentence_length = prepare_tokenizer(dataset,1)
print(eng_vocab_size,spa_vocab_size,eng_max_sentence_length,spa_max_sentence_length)

trainX, trainY =  preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, train, one_hot=False)
testX, testY = preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, test, one_hot=False)
print(trainX.shape, trainY.shape, testX.shape, testY.shape)

model1_1 = define_model_embedding(eng_vocab_size, spa_vocab_size, eng_max_sentence_length, spa_max_sentence_length, units)
create_model(model1_1,loss_func,learning_rate)
plot_model(model1_1, to_file='model_images/cp_model_1_1_m.png', show_shapes=True)
#train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model, model_save_file_name, history_save_file_name)
train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model1_1, model_save_file_name,history_save_file_name)
graph_loss_vs_epochs(model1_1.history, 'loss_vs_epochs_images/cp_model_1_1_le.png', 'Model 1 var 1')
# Out:
# 2272 4510 5 8
# (8000, 5) (8000, 8) (2000, 5) (2000, 8)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 5, 256)            581632
#
#  gru_10 (GRU)                (None, 256)               394752
#
#  repeat_vector_5 (RepeatVect  (None, 8, 256)           0
#  or)
#
#  gru_11 (GRU)                (None, 8, 256)            394752
#
#  time_distributed_5 (TimeDis  (None, 8, 4510)          1159070
#  tributed)
#
# =================================================================
# Total params: 2,530,206
# Trainable params: 2,530,206
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/32
#
# Epoch 1: val_loss improved from inf to 2.65501, saving model to Models\cp_model_1_1.h5
# 125/125 - 36s - loss: 3.4275 - acc: 0.6368 - val_loss: 2.6550 - val_acc: 0.6507 - 36s/epoch - 284ms/step
# Epoch 2/32
#
# Epoch 2: val_loss improved from 2.65501 to 2.55942, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 2.5175 - acc: 0.6529 - val_loss: 2.5594 - val_acc: 0.6565 - 24s/epoch - 195ms/step
# Epoch 3/32
#
# Epoch 3: val_loss improved from 2.55942 to 2.51592, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 2.4164 - acc: 0.6575 - val_loss: 2.5159 - val_acc: 0.6605 - 24s/epoch - 193ms/step
# Epoch 4/32
#
# Epoch 4: val_loss improved from 2.51592 to 2.48733, saving model to Models\cp_model_1_1.h5
# 125/125 - 25s - loss: 2.3490 - acc: 0.6606 - val_loss: 2.4873 - val_acc: 0.6626 - 25s/epoch - 197ms/step
# Epoch 5/32
#
# Epoch 5: val_loss improved from 2.48733 to 2.44557, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 2.2803 - acc: 0.6644 - val_loss: 2.4456 - val_acc: 0.6679 - 24s/epoch - 190ms/step
# Epoch 6/32
#
# Epoch 6: val_loss improved from 2.44557 to 2.39898, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 2.1989 - acc: 0.6704 - val_loss: 2.3990 - val_acc: 0.6691 - 24s/epoch - 191ms/step
# Epoch 7/32
#
# Epoch 7: val_loss improved from 2.39898 to 2.33509, saving model to Models\cp_model_1_1.h5
# 125/125 - 23s - loss: 2.0990 - acc: 0.6772 - val_loss: 2.3351 - val_acc: 0.6796 - 23s/epoch - 188ms/step
# Epoch 8/32
#
# Epoch 8: val_loss improved from 2.33509 to 2.28327, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.9912 - acc: 0.6862 - val_loss: 2.2833 - val_acc: 0.6852 - 24s/epoch - 193ms/step
# Epoch 9/32
#
# Epoch 9: val_loss improved from 2.28327 to 2.23887, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.8836 - acc: 0.6943 - val_loss: 2.2389 - val_acc: 0.6906 - 24s/epoch - 192ms/step
# Epoch 10/32
#
# Epoch 10: val_loss improved from 2.23887 to 2.20044, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.7781 - acc: 0.7032 - val_loss: 2.2004 - val_acc: 0.6947 - 24s/epoch - 192ms/step
# Epoch 11/32
#
# Epoch 11: val_loss improved from 2.20044 to 2.15422, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.6735 - acc: 0.7112 - val_loss: 2.1542 - val_acc: 0.6994 - 24s/epoch - 193ms/step
# Epoch 12/32
#
# Epoch 12: val_loss improved from 2.15422 to 2.11811, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.5732 - acc: 0.7190 - val_loss: 2.1181 - val_acc: 0.7063 - 24s/epoch - 190ms/step
# Epoch 13/32
#
# Epoch 13: val_loss improved from 2.11811 to 2.08441, saving model to Models\cp_model_1_1.h5
# 125/125 - 25s - loss: 1.4729 - acc: 0.7279 - val_loss: 2.0844 - val_acc: 0.7088 - 25s/epoch - 197ms/step
# Epoch 14/32
#
# Epoch 14: val_loss improved from 2.08441 to 2.05294, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.3773 - acc: 0.7364 - val_loss: 2.0529 - val_acc: 0.7163 - 24s/epoch - 192ms/step
# Epoch 15/32
#
# Epoch 15: val_loss improved from 2.05294 to 2.02651, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.2818 - acc: 0.7459 - val_loss: 2.0265 - val_acc: 0.7179 - 24s/epoch - 189ms/step
# Epoch 16/32
#
# Epoch 16: val_loss improved from 2.02651 to 1.99825, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.1937 - acc: 0.7548 - val_loss: 1.9982 - val_acc: 0.7189 - 24s/epoch - 189ms/step
# Epoch 17/32
#
# Epoch 17: val_loss improved from 1.99825 to 1.98599, saving model to Models\cp_model_1_1.h5
# 125/125 - 25s - loss: 1.1087 - acc: 0.7651 - val_loss: 1.9860 - val_acc: 0.7231 - 25s/epoch - 199ms/step
# Epoch 18/32
#
# Epoch 18: val_loss improved from 1.98599 to 1.96696, saving model to Models\cp_model_1_1.h5
# 125/125 - 24s - loss: 1.0292 - acc: 0.7745 - val_loss: 1.9670 - val_acc: 0.7243 - 24s/epoch - 190ms/step
# Epoch 19/32
#
# Epoch 19: val_loss improved from 1.96696 to 1.95775, saving model to Models\cp_model_1_1.h5
# 125/125 - 23s - loss: 0.9536 - acc: 0.7848 - val_loss: 1.9577 - val_acc: 0.7260 - 23s/epoch - 185ms/step
# Epoch 20/32
#
# Epoch 20: val_loss improved from 1.95775 to 1.93908, saving model to Models\cp_model_1_1.h5
# 125/125 - 23s - loss: 0.8851 - acc: 0.7955 - val_loss: 1.9391 - val_acc: 0.7294 - 23s/epoch - 184ms/step
# Epoch 21/32
#
# Epoch 21: val_loss did not improve from 1.93908
# 125/125 - 23s - loss: 0.8195 - acc: 0.8060 - val_loss: 1.9425 - val_acc: 0.7324 - 23s/epoch - 185ms/step
# Epoch 22/32
#
# Epoch 22: val_loss did not improve from 1.93908
# 125/125 - 23s - loss: 0.7608 - acc: 0.8156 - val_loss: 1.9412 - val_acc: 0.7325 - 23s/epoch - 187ms/step
# Epoch 23/32
#
# Epoch 23: val_loss improved from 1.93908 to 1.93120, saving model to Models\cp_model_1_1.h5
# 125/125 - 25s - loss: 0.7098 - acc: 0.8262 - val_loss: 1.9312 - val_acc: 0.7322 - 25s/epoch - 204ms/step
# Epoch 24/32
#
# Epoch 24: val_loss did not improve from 1.93120
# 125/125 - 23s - loss: 0.6604 - acc: 0.8348 - val_loss: 1.9409 - val_acc: 0.7319 - 23s/epoch - 185ms/step
# Epoch 25/32
#
# Epoch 25: val_loss did not improve from 1.93120
# 125/125 - 23s - loss: 0.6160 - acc: 0.8438 - val_loss: 1.9387 - val_acc: 0.7337 - 23s/epoch - 184ms/step
# Epoch 26/32
#
# Epoch 26: val_loss did not improve from 1.93120
# 125/125 - 23s - loss: 0.5758 - acc: 0.8511 - val_loss: 1.9414 - val_acc: 0.7343 - 23s/epoch - 186ms/step
# Epoch 27/32
#
# Epoch 27: val_loss did not improve from 1.93120
# 125/125 - 24s - loss: 0.5407 - acc: 0.8572 - val_loss: 1.9438 - val_acc: 0.7334 - 24s/epoch - 190ms/step
# Epoch 28/32
#
# Epoch 28: val_loss did not improve from 1.93120
# 125/125 - 24s - loss: 0.5061 - acc: 0.8651 - val_loss: 1.9481 - val_acc: 0.7342 - 24s/epoch - 188ms/step
# Epoch 29/32
#
# Epoch 29: val_loss did not improve from 1.93120
# 125/125 - 23s - loss: 0.4782 - acc: 0.8703 - val_loss: 1.9528 - val_acc: 0.7321 - 23s/epoch - 184ms/step
# Epoch 30/32
#
# Epoch 30: val_loss did not improve from 1.93120
# 125/125 - 24s - loss: 0.4497 - acc: 0.8756 - val_loss: 1.9617 - val_acc: 0.7318 - 24s/epoch - 189ms/step
# Epoch 31/32
#
# Epoch 31: val_loss did not improve from 1.93120
# 125/125 - 23s - loss: 0.4250 - acc: 0.8802 - val_loss: 1.9691 - val_acc: 0.7319 - 23s/epoch - 185ms/step
# Epoch 32/32
#
# Epoch 32: val_loss did not improve from 1.93120
# 125/125 - 23s - loss: 0.4034 - acc: 0.8836 - val_loss: 1.9777 - val_acc: 0.7316 - 23s/epoch - 185ms/step

# %% [markdown]
# ### Variante 2

# %%
ds_filename, train_ds_fn, test_ds_fn = 'dataset/english-spanish-both-10000.txt', 'dataset/english-spanish-train-10000.txt','dataset/english-spanish-test-10000.txt'
units = 32
learning_rate = 0.005
loss_func='sparse_categorical_crossentropy'
epochs=32
batch_size=64
model_save_file_name='Models/cp_model_1_2.h5'
history_save_file_name="cp_history_1_2.npy"

dataset,train,test=load_data(ds_filename, train_ds_fn, test_ds_fn)

eng_tokenizer,eng_vocab_size,eng_max_sentence_length = prepare_tokenizer(dataset,0)
spa_tokenizer,spa_vocab_size,spa_max_sentence_length = prepare_tokenizer(dataset,1)
print(eng_vocab_size,spa_vocab_size,eng_max_sentence_length,spa_max_sentence_length)

trainX, trainY =  preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, train, one_hot=False)
testX, testY = preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, test, one_hot=False)
print(trainX.shape, trainY.shape, testX.shape, testY.shape)

model1_2 = define_model_embedding(eng_vocab_size, spa_vocab_size, eng_max_sentence_length, spa_max_sentence_length, units,"softmax")
create_model(model1_2,loss_func,learning_rate)
plot_model(model1_2, to_file='model_images/cp_model_1_2_m.png', show_shapes=True)
train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model1_2, model_save_file_name,history_save_file_name)
graph_loss_vs_epochs(model1_2.history, 'loss_vs_epochs_images/cp_model_1_2_le.png', 'Model 1 var 2')
# Out:
# 2272 4510 5 8
# (8000, 5) (8000, 8) (2000, 5) (2000, 8)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 5, 32)             72704
#
#  gru_12 (GRU)                (None, 32)                6336
#
#  repeat_vector_6 (RepeatVect  (None, 8, 32)            0
#  or)
#
#  gru_13 (GRU)                (None, 8, 32)             6336
#
#  time_distributed_6 (TimeDis  (None, 8, 4510)          148830
#  tributed)
#
# =================================================================
# Total params: 234,206
# Trainable params: 234,206
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/32
#
# Epoch 1: val_loss improved from inf to 2.66029, saving model to Models\cp_model_1_2.h5
# 125/125 - 22s - loss: 3.6305 - acc: 0.6356 - val_loss: 2.6603 - val_acc: 0.6417 - 22s/epoch - 174ms/step
# Epoch 2/32
#
# Epoch 2: val_loss improved from 2.66029 to 2.58313, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.5719 - acc: 0.6451 - val_loss: 2.5831 - val_acc: 0.6511 - 13s/epoch - 101ms/step
# Epoch 3/32
#
# Epoch 3: val_loss improved from 2.58313 to 2.53300, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.4711 - acc: 0.6516 - val_loss: 2.5330 - val_acc: 0.6539 - 13s/epoch - 101ms/step
# Epoch 4/32
#
# Epoch 4: val_loss improved from 2.53300 to 2.49577, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.3951 - acc: 0.6564 - val_loss: 2.4958 - val_acc: 0.6568 - 13s/epoch - 101ms/step
# Epoch 5/32
#
# Epoch 5: val_loss improved from 2.49577 to 2.46964, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.3380 - acc: 0.6597 - val_loss: 2.4696 - val_acc: 0.6611 - 13s/epoch - 101ms/step
# Epoch 6/32
#
# Epoch 6: val_loss improved from 2.46964 to 2.43879, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.2823 - acc: 0.6640 - val_loss: 2.4388 - val_acc: 0.6639 - 13s/epoch - 101ms/step
# Epoch 7/32
#
# Epoch 7: val_loss improved from 2.43879 to 2.41175, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.2237 - acc: 0.6676 - val_loss: 2.4118 - val_acc: 0.6678 - 13s/epoch - 100ms/step
# Epoch 8/32
#
# Epoch 8: val_loss improved from 2.41175 to 2.37326, saving model to Models\cp_model_1_2.h5
# 125/125 - 12s - loss: 2.1544 - acc: 0.6733 - val_loss: 2.3733 - val_acc: 0.6714 - 12s/epoch - 100ms/step
# Epoch 9/32
#
# Epoch 9: val_loss improved from 2.37326 to 2.31935, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 2.0746 - acc: 0.6798 - val_loss: 2.3194 - val_acc: 0.6783 - 13s/epoch - 101ms/step
# Epoch 10/32
#
# Epoch 10: val_loss improved from 2.31935 to 2.27339, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.9843 - acc: 0.6881 - val_loss: 2.2734 - val_acc: 0.6837 - 13s/epoch - 101ms/step
# Epoch 11/32
#
# Epoch 11: val_loss improved from 2.27339 to 2.25006, saving model to Models\cp_model_1_2.h5
# 125/125 - 12s - loss: 1.9025 - acc: 0.6945 - val_loss: 2.2501 - val_acc: 0.6862 - 12s/epoch - 99ms/step
# Epoch 12/32
#
# Epoch 12: val_loss improved from 2.25006 to 2.22730, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.8297 - acc: 0.6995 - val_loss: 2.2273 - val_acc: 0.6864 - 13s/epoch - 101ms/step
# Epoch 13/32
#
# Epoch 13: val_loss improved from 2.22730 to 2.19486, saving model to Models\cp_model_1_2.h5
# 125/125 - 12s - loss: 1.7554 - acc: 0.7057 - val_loss: 2.1949 - val_acc: 0.6930 - 12s/epoch - 100ms/step
# Epoch 14/32
#
# Epoch 14: val_loss improved from 2.19486 to 2.17839, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.6867 - acc: 0.7105 - val_loss: 2.1784 - val_acc: 0.6929 - 13s/epoch - 102ms/step
# Epoch 15/32
#
# Epoch 15: val_loss improved from 2.17839 to 2.15473, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.6172 - acc: 0.7164 - val_loss: 2.1547 - val_acc: 0.6974 - 13s/epoch - 105ms/step
# Epoch 16/32
#
# Epoch 16: val_loss improved from 2.15473 to 2.13851, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.5518 - acc: 0.7225 - val_loss: 2.1385 - val_acc: 0.7006 - 13s/epoch - 102ms/step
# Epoch 17/32
#
# Epoch 17: val_loss improved from 2.13851 to 2.13236, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.4918 - acc: 0.7274 - val_loss: 2.1324 - val_acc: 0.7001 - 13s/epoch - 100ms/step
# Epoch 18/32
#
# Epoch 18: val_loss improved from 2.13236 to 2.11245, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.4346 - acc: 0.7322 - val_loss: 2.1124 - val_acc: 0.7059 - 13s/epoch - 105ms/step
# Epoch 19/32
#
# Epoch 19: val_loss did not improve from 2.11245
# 125/125 - 13s - loss: 1.3780 - acc: 0.7374 - val_loss: 2.1135 - val_acc: 0.7040 - 13s/epoch - 100ms/step
# Epoch 20/32
#
# Epoch 20: val_loss improved from 2.11245 to 2.10831, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.3289 - acc: 0.7406 - val_loss: 2.1083 - val_acc: 0.7066 - 13s/epoch - 103ms/step
# Epoch 21/32
#
# Epoch 21: val_loss improved from 2.10831 to 2.10654, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.2802 - acc: 0.7468 - val_loss: 2.1065 - val_acc: 0.7056 - 13s/epoch - 100ms/step
# Epoch 22/32
#
# Epoch 22: val_loss improved from 2.10654 to 2.09853, saving model to Models\cp_model_1_2.h5
# 125/125 - 13s - loss: 1.2365 - acc: 0.7511 - val_loss: 2.0985 - val_acc: 0.7059 - 13s/epoch - 104ms/step
# Epoch 23/32
#
# Epoch 23: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 1.1965 - acc: 0.7539 - val_loss: 2.1022 - val_acc: 0.7096 - 13s/epoch - 104ms/step
# Epoch 24/32
#
# Epoch 24: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 1.1546 - acc: 0.7585 - val_loss: 2.1034 - val_acc: 0.7067 - 13s/epoch - 103ms/step
# Epoch 25/32
#
# Epoch 25: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 1.1209 - acc: 0.7621 - val_loss: 2.1040 - val_acc: 0.7086 - 13s/epoch - 101ms/step
# Epoch 26/32
#
# Epoch 26: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 1.0855 - acc: 0.7674 - val_loss: 2.1143 - val_acc: 0.7072 - 13s/epoch - 103ms/step
# Epoch 27/32
#
# Epoch 27: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 1.0531 - acc: 0.7704 - val_loss: 2.1082 - val_acc: 0.7091 - 13s/epoch - 102ms/step
# Epoch 28/32
#
# Epoch 28: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 1.0244 - acc: 0.7747 - val_loss: 2.1096 - val_acc: 0.7086 - 13s/epoch - 101ms/step
# Epoch 29/32
#
# Epoch 29: val_loss did not improve from 2.09853
# 125/125 - 13s - loss: 0.9949 - acc: 0.7786 - val_loss: 2.1124 - val_acc: 0.7094 - 13s/epoch - 105ms/step
# Epoch 30/32
#
# Epoch 30: val_loss did not improve from 2.09853
# 125/125 - 74s - loss: 0.9680 - acc: 0.7824 - val_loss: 2.1188 - val_acc: 0.7124 - 74s/epoch - 596ms/step
# Epoch 31/32
#
# Epoch 31: val_loss did not improve from 2.09853
# 125/125 - 11s - loss: 0.9416 - acc: 0.7872 - val_loss: 2.1162 - val_acc: 0.7114 - 11s/epoch - 89ms/step
# Epoch 32/32
#
# Epoch 32: val_loss did not improve from 2.09853
# 125/125 - 9s - loss: 0.9195 - acc: 0.7902 - val_loss: 2.1185 - val_acc: 0.7119 - 9s/epoch - 73ms/step

# %% [markdown]
# ### Variante 3

# %%
ds_filename, train_ds_fn, test_ds_fn = 'dataset/english-spanish-both-10000.txt', 'dataset/english-spanish-train-10000.txt','dataset/english-spanish-test-10000.txt'
units = 64
learning_rate = 0.005
loss_func='sparse_categorical_crossentropy'
epochs=64
batch_size=128
model_save_file_name='Models/cp_model_1_3.h5'
history_save_file_name="cp_history_1_3.npy"

dataset,train,test=load_data(ds_filename, train_ds_fn, test_ds_fn)

eng_tokenizer,eng_vocab_size,eng_max_sentence_length = prepare_tokenizer(dataset,0)
spa_tokenizer,spa_vocab_size,spa_max_sentence_length = prepare_tokenizer(dataset,1)
print(eng_vocab_size,spa_vocab_size,eng_max_sentence_length,spa_max_sentence_length)

trainX, trainY =  preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, train, one_hot=False)
testX, testY = preprocess_input(eng_tokenizer, eng_max_sentence_length, spa_tokenizer, spa_max_sentence_length,spa_vocab_size, test, one_hot=False)
print(trainX.shape, trainY.shape, testX.shape, testY.shape)

model1_3 = define_model_embedding(eng_vocab_size, spa_vocab_size, eng_max_sentence_length, spa_max_sentence_length, units,"sigmoid")
create_model(model1_3,loss_func,learning_rate)
plot_model(model1_3, to_file='model_images/cp_model_1_3_m.png', show_shapes=True)
train_evaluate_model(trainX, trainY, testX,testY, epochs, batch_size, model1_3, model_save_file_name,history_save_file_name)
graph_loss_vs_epochs(model1_3.history, 'loss_vs_epochs_images/cp_model_1_3_le.png', 'Model 1 var 3')
# Out:
# 2272 4510 5 8
# (8000, 5) (8000, 8) (2000, 5) (2000, 8)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 5, 64)             145408
#
#  gru_14 (GRU)                (None, 64)                24960
#
#  repeat_vector_7 (RepeatVect  (None, 8, 64)            0
#  or)
#
#  gru_15 (GRU)                (None, 8, 64)             24960
#
#  time_distributed_7 (TimeDis  (None, 8, 4510)          293150
#  tributed)
#
# =================================================================
# Total params: 488,478
# Trainable params: 488,478
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/64
#
# Epoch 1: val_loss improved from inf to 4.30447, saving model to Models\cp_model_1_3.h5
# 63/63 - 14s - loss: 5.5783 - acc: 0.6306 - val_loss: 4.3045 - val_acc: 0.6417 - 14s/epoch - 219ms/step
# Epoch 2/64
#
# Epoch 2: val_loss improved from 4.30447 to 2.86554, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 3.4973 - acc: 0.6404 - val_loss: 2.8655 - val_acc: 0.6417 - 8s/epoch - 133ms/step
# Epoch 3/64
#
# Epoch 3: val_loss improved from 2.86554 to 2.67513, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 2.6992 - acc: 0.6411 - val_loss: 2.6751 - val_acc: 0.6417 - 9s/epoch - 139ms/step
# Epoch 4/64
#
# Epoch 4: val_loss improved from 2.67513 to 2.58434, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 2.5542 - acc: 0.6410 - val_loss: 2.5843 - val_acc: 0.6417 - 9s/epoch - 142ms/step
# Epoch 5/64
#
# Epoch 5: val_loss improved from 2.58434 to 2.54744, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.4709 - acc: 0.6410 - val_loss: 2.5474 - val_acc: 0.6417 - 8s/epoch - 124ms/step
# Epoch 6/64
#
# Epoch 6: val_loss improved from 2.54744 to 2.52208, saving model to Models\cp_model_1_3.h5
# 63/63 - 7s - loss: 2.4199 - acc: 0.6417 - val_loss: 2.5221 - val_acc: 0.6467 - 7s/epoch - 117ms/step
# Epoch 7/64
#
# Epoch 7: val_loss improved from 2.52208 to 2.50317, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.3622 - acc: 0.6587 - val_loss: 2.5032 - val_acc: 0.6615 - 8s/epoch - 120ms/step
# Epoch 8/64
#
# Epoch 8: val_loss improved from 2.50317 to 2.47863, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.3176 - acc: 0.6598 - val_loss: 2.4786 - val_acc: 0.6614 - 8s/epoch - 124ms/step
# Epoch 9/64
#
# Epoch 9: val_loss improved from 2.47863 to 2.46432, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.2778 - acc: 0.6626 - val_loss: 2.4643 - val_acc: 0.6623 - 8s/epoch - 120ms/step
# Epoch 10/64
#
# Epoch 10: val_loss improved from 2.46432 to 2.45255, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.2411 - acc: 0.6636 - val_loss: 2.4525 - val_acc: 0.6621 - 8s/epoch - 120ms/step
# Epoch 11/64
#
# Epoch 11: val_loss improved from 2.45255 to 2.44029, saving model to Models\cp_model_1_3.h5
# 63/63 - 7s - loss: 2.2085 - acc: 0.6648 - val_loss: 2.4403 - val_acc: 0.6636 - 7s/epoch - 118ms/step
# Epoch 12/64
#
# Epoch 12: val_loss improved from 2.44029 to 2.41836, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.1700 - acc: 0.6660 - val_loss: 2.4184 - val_acc: 0.6638 - 8s/epoch - 123ms/step
# Epoch 13/64
#
# Epoch 13: val_loss improved from 2.41836 to 2.40284, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.1245 - acc: 0.6677 - val_loss: 2.4028 - val_acc: 0.6672 - 8s/epoch - 130ms/step
# Epoch 14/64
#
# Epoch 14: val_loss improved from 2.40284 to 2.39843, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.0770 - acc: 0.6696 - val_loss: 2.3984 - val_acc: 0.6633 - 8s/epoch - 129ms/step
# Epoch 15/64
#
# Epoch 15: val_loss improved from 2.39843 to 2.34814, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 2.0264 - acc: 0.6722 - val_loss: 2.3481 - val_acc: 0.6654 - 8s/epoch - 123ms/step
# Epoch 16/64
#
# Epoch 16: val_loss improved from 2.34814 to 2.31366, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.9724 - acc: 0.6763 - val_loss: 2.3137 - val_acc: 0.6740 - 8s/epoch - 131ms/step
# Epoch 17/64
#
# Epoch 17: val_loss improved from 2.31366 to 2.29169, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.9168 - acc: 0.6805 - val_loss: 2.2917 - val_acc: 0.6762 - 8s/epoch - 130ms/step
# Epoch 18/64
#
# Epoch 18: val_loss improved from 2.29169 to 2.25174, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 1.8582 - acc: 0.6878 - val_loss: 2.2517 - val_acc: 0.6814 - 9s/epoch - 145ms/step
# Epoch 19/64
#
# Epoch 19: val_loss improved from 2.25174 to 2.22182, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.7982 - acc: 0.6921 - val_loss: 2.2218 - val_acc: 0.6866 - 8s/epoch - 133ms/step
# Epoch 20/64
#
# Epoch 20: val_loss improved from 2.22182 to 2.19818, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 1.7386 - acc: 0.6986 - val_loss: 2.1982 - val_acc: 0.6881 - 9s/epoch - 136ms/step
# Epoch 21/64
#
# Epoch 21: val_loss improved from 2.19818 to 2.17717, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 1.6826 - acc: 0.7037 - val_loss: 2.1772 - val_acc: 0.6944 - 9s/epoch - 139ms/step
# Epoch 22/64
#
# Epoch 22: val_loss improved from 2.17717 to 2.15171, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 1.6261 - acc: 0.7092 - val_loss: 2.1517 - val_acc: 0.6963 - 9s/epoch - 136ms/step
# Epoch 23/64
#
# Epoch 23: val_loss improved from 2.15171 to 2.13063, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.5730 - acc: 0.7156 - val_loss: 2.1306 - val_acc: 0.6959 - 8s/epoch - 130ms/step
# Epoch 24/64
#
# Epoch 24: val_loss improved from 2.13063 to 2.11598, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.5204 - acc: 0.7194 - val_loss: 2.1160 - val_acc: 0.7008 - 8s/epoch - 131ms/step
# Epoch 25/64
#
# Epoch 25: val_loss improved from 2.11598 to 2.09603, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.4666 - acc: 0.7249 - val_loss: 2.0960 - val_acc: 0.7018 - 8s/epoch - 127ms/step
# Epoch 26/64
#
# Epoch 26: val_loss improved from 2.09603 to 2.08302, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.4189 - acc: 0.7286 - val_loss: 2.0830 - val_acc: 0.7017 - 8s/epoch - 124ms/step
# Epoch 27/64
#
# Epoch 27: val_loss improved from 2.08302 to 2.07473, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.3713 - acc: 0.7324 - val_loss: 2.0747 - val_acc: 0.7010 - 8s/epoch - 131ms/step
# Epoch 28/64
#
# Epoch 28: val_loss improved from 2.07473 to 2.06541, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.3246 - acc: 0.7375 - val_loss: 2.0654 - val_acc: 0.7031 - 8s/epoch - 130ms/step
# Epoch 29/64
#
# Epoch 29: val_loss improved from 2.06541 to 2.05340, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.2819 - acc: 0.7400 - val_loss: 2.0534 - val_acc: 0.7080 - 8s/epoch - 127ms/step
# Epoch 30/64
#
# Epoch 30: val_loss improved from 2.05340 to 2.04770, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.2417 - acc: 0.7453 - val_loss: 2.0477 - val_acc: 0.7062 - 8s/epoch - 126ms/step
# Epoch 31/64
#
# Epoch 31: val_loss improved from 2.04770 to 2.03999, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.2044 - acc: 0.7491 - val_loss: 2.0400 - val_acc: 0.7076 - 8s/epoch - 126ms/step
# Epoch 32/64
#
# Epoch 32: val_loss improved from 2.03999 to 2.03430, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.1680 - acc: 0.7527 - val_loss: 2.0343 - val_acc: 0.7089 - 8s/epoch - 127ms/step
# Epoch 33/64
#
# Epoch 33: val_loss improved from 2.03430 to 2.03274, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 1.1347 - acc: 0.7563 - val_loss: 2.0327 - val_acc: 0.7089 - 8s/epoch - 125ms/step
# Epoch 34/64
#
# Epoch 34: val_loss did not improve from 2.03274
# 63/63 - 9s - loss: 1.1031 - acc: 0.7601 - val_loss: 2.0334 - val_acc: 0.7114 - 9s/epoch - 150ms/step
# Epoch 35/64
#
# Epoch 35: val_loss improved from 2.03274 to 2.02575, saving model to Models\cp_model_1_3.h5
# 63/63 - 9s - loss: 1.0703 - acc: 0.7652 - val_loss: 2.0257 - val_acc: 0.7100 - 9s/epoch - 137ms/step
# Epoch 36/64
#
# Epoch 36: val_loss did not improve from 2.02575
# 63/63 - 8s - loss: 1.0372 - acc: 0.7690 - val_loss: 2.0332 - val_acc: 0.7071 - 8s/epoch - 129ms/step
# Epoch 37/64
#
# Epoch 37: val_loss did not improve from 2.02575
# 63/63 - 8s - loss: 1.0094 - acc: 0.7730 - val_loss: 2.0337 - val_acc: 0.7096 - 8s/epoch - 126ms/step
# Epoch 38/64
#
# Epoch 38: val_loss did not improve from 2.02575
# 63/63 - 8s - loss: 0.9783 - acc: 0.7776 - val_loss: 2.0323 - val_acc: 0.7099 - 8s/epoch - 132ms/step
# Epoch 39/64
#
# Epoch 39: val_loss improved from 2.02575 to 2.02536, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 0.9533 - acc: 0.7809 - val_loss: 2.0254 - val_acc: 0.7113 - 8s/epoch - 134ms/step
# Epoch 40/64
#
# Epoch 40: val_loss improved from 2.02536 to 2.02369, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 0.9261 - acc: 0.7852 - val_loss: 2.0237 - val_acc: 0.7105 - 8s/epoch - 135ms/step
# Epoch 41/64
#
# Epoch 41: val_loss did not improve from 2.02369
# 63/63 - 8s - loss: 0.9037 - acc: 0.7898 - val_loss: 2.0272 - val_acc: 0.7094 - 8s/epoch - 131ms/step
# Epoch 42/64
#
# Epoch 42: val_loss improved from 2.02369 to 2.01648, saving model to Models\cp_model_1_3.h5
# 63/63 - 8s - loss: 0.8800 - acc: 0.7925 - val_loss: 2.0165 - val_acc: 0.7153 - 8s/epoch - 131ms/step
# Epoch 43/64
#
# Epoch 43: val_loss did not improve from 2.01648
# 63/63 - 8s - loss: 0.8546 - acc: 0.7981 - val_loss: 2.0223 - val_acc: 0.7165 - 8s/epoch - 131ms/step
# Epoch 44/64
#
# Epoch 44: val_loss did not improve from 2.01648
# 63/63 - 8s - loss: 0.8336 - acc: 0.8007 - val_loss: 2.0184 - val_acc: 0.7125 - 8s/epoch - 127ms/step
# Epoch 45/64
#
# Epoch 45: val_loss did not improve from 2.01648
# 63/63 - 8s - loss: 0.8144 - acc: 0.8053 - val_loss: 2.0194 - val_acc: 0.7139 - 8s/epoch - 128ms/step
# Epoch 46/64
#
# Epoch 46: val_loss did not improve from 2.01648
# 63/63 - 8s - loss: 0.7940 - acc: 0.8066 - val_loss: 2.0223 - val_acc: 0.7153 - 8s/epoch - 130ms/step
# Epoch 47/64
#
# Epoch 47: val_loss did not improve from 2.01648
# 63/63 - 8s - loss: 0.7723 - acc: 0.8119 - val_loss: 2.0262 - val_acc: 0.7152 - 8s/epoch - 128ms/step
# Epoch 48/64
#
# Epoch 48: val_loss did not improve from 2.01648
# 63/63 - 10s - loss: 0.7543 - acc: 0.8161 - val_loss: 2.0235 - val_acc: 0.7167 - 10s/epoch - 166ms/step
# Epoch 49/64
#
# Epoch 49: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.7371 - acc: 0.8192 - val_loss: 2.0293 - val_acc: 0.7111 - 9s/epoch - 144ms/step
# Epoch 50/64
#
# Epoch 50: val_loss did not improve from 2.01648
# 63/63 - 10s - loss: 0.7211 - acc: 0.8220 - val_loss: 2.0266 - val_acc: 0.7147 - 10s/epoch - 156ms/step
# Epoch 51/64
#
# Epoch 51: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.7071 - acc: 0.8238 - val_loss: 2.0367 - val_acc: 0.7144 - 9s/epoch - 141ms/step
# Epoch 52/64
#
# Epoch 52: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6916 - acc: 0.8273 - val_loss: 2.0399 - val_acc: 0.7121 - 9s/epoch - 139ms/step
# Epoch 53/64
#
# Epoch 53: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6767 - acc: 0.8303 - val_loss: 2.0441 - val_acc: 0.7154 - 9s/epoch - 144ms/step
# Epoch 54/64
#
# Epoch 54: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6635 - acc: 0.8323 - val_loss: 2.0435 - val_acc: 0.7140 - 9s/epoch - 150ms/step
# Epoch 55/64
#
# Epoch 55: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6474 - acc: 0.8358 - val_loss: 2.0441 - val_acc: 0.7153 - 9s/epoch - 146ms/step
# Epoch 56/64
#
# Epoch 56: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6366 - acc: 0.8374 - val_loss: 2.0628 - val_acc: 0.7137 - 9s/epoch - 150ms/step
# Epoch 57/64
#
# Epoch 57: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6263 - acc: 0.8393 - val_loss: 2.0597 - val_acc: 0.7137 - 9s/epoch - 148ms/step
# Epoch 58/64
#
# Epoch 58: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6134 - acc: 0.8422 - val_loss: 2.0580 - val_acc: 0.7164 - 9s/epoch - 143ms/step
# Epoch 59/64
#
# Epoch 59: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.6012 - acc: 0.8434 - val_loss: 2.0595 - val_acc: 0.7163 - 9s/epoch - 139ms/step
# Epoch 60/64
#
# Epoch 60: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.5892 - acc: 0.8462 - val_loss: 2.0637 - val_acc: 0.7182 - 9s/epoch - 144ms/step
# Epoch 61/64
#
# Epoch 61: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.5799 - acc: 0.8479 - val_loss: 2.0735 - val_acc: 0.7164 - 9s/epoch - 144ms/step
# Epoch 62/64
#
# Epoch 62: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.5723 - acc: 0.8492 - val_loss: 2.0792 - val_acc: 0.7148 - 9s/epoch - 138ms/step
# Epoch 63/64
#
# Epoch 63: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.5601 - acc: 0.8517 - val_loss: 2.0912 - val_acc: 0.7143 - 9s/epoch - 138ms/step
# Epoch 64/64
#
# Epoch 64: val_loss did not improve from 2.01648
# 63/63 - 9s - loss: 0.5511 - acc: 0.8535 - val_loss: 2.0896 - val_acc: 0.7160 - 9s/epoch - 136ms/step

# %%
hist1 = load_history("cp_history_1_1.npy")
hist2 = load_history("cp_history_1_2.npy")
hist3 = load_history("cp_history_1_3.npy")
for x in ['loss']:
    plt.plot(hist1[x],label="Historic 1")
    plt.plot(hist2[x],label="Historic 2")
    plt.plot(hist3[x],label="Historic 3")
plt.legend()
plt.xlabel("EPOCHS",fontsize=13)
plt.ylabel("LOSS",fontsize=13)
# Out:
# Text(0, 0.5, 'LOSS')
