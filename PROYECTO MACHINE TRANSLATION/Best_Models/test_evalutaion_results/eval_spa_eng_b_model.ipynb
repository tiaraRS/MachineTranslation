# %% [markdown]
# ##### Spanish-to-English Model Evaluation
#     Here we will evaluate the model for spanish-to-english translation, with the test dataset.

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, tokenizer, source)
		raw_src,raw_target = raw_dataset[i]
		print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())

# load datasets
dataset = load_clean_sentences('dataset/spanish-english-both-80000.txt')
train = load_clean_sentences('dataset/spanish-english-train-80000.txt')
test = load_clean_sentences('dataset/spanish-english-test-80000.txt')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
spa_tokenizer = create_tokenizer(dataset[:, 1])
spa_vocab_size = len(spa_tokenizer.word_index) + 1
spa_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
testX = encode_sequences(eng_tokenizer, eng_length, test[:, 0])

# load complete model spanish english
model = load_model('Models\model_spa_eng_80000.h5')
# Out:
# train
# test

# %%
print("The document count",eng_tokenizer.document_count)
print("The count of words",len(eng_tokenizer.word_counts))
#print("The word index",eng_tokenizer.word_index)
print("The document count",spa_tokenizer.document_count)
print("The count of words",len(spa_tokenizer.word_counts))
# Out:
# The document count 80000
# The count of words 20905
# The document count 80000
# The count of words 11203

# %%
#save tokenizers to use in UI API
import pickle

# saving
with open('Tokenizers/spa_tokenizer_80000_eng_spa.pickle', 'wb') as handle:
    pickle.dump(spa_tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('Tokenizers/spa_tokenizer_80000_eng_spa.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)  
    print(len(tokenizer.word_index) + 1)
# Out:
# [[5, 24]]
# 11204

# %%
print('test')
evaluate_model(model, spa_tokenizer, testX, test)
# Out:
# test
# src=[el dictador llego al poder hace quince anos], target=[the dictator came to power fifteen years ago], predicted=[the the ran the he he fifteen the]
# src=[realmente quiero otra oportunidad], target=[i really want another chance], predicted=[i really want another chance]
# src=[no tengo carro pero mi hermana si], target=[i have a car but my sister does], predicted=[i have a but but but sister]
# src=[no pongas el vaso cerca del borde de la mesa], target=[put the glass near the edge of the table], predicted=[take the the of of the table table table]
# src=[a tom le gusta ver television], target=[tom likes watching tv], predicted=[tom likes watching tv]
# src=[subi de puntillas a mi dormitorio], target=[i went up to my bedroom on tiptoe], predicted=[i left out head side room]
# src=[por que me preguntas esto], target=[why are you asking me this], predicted=[why did you ask for me]
# src=[tom no debe ir a ningun lado], target=[tom have to go anywhere], predicted=[tom have be anywhere anywhere]
# src=[vamos a ayudarlo para que tenga exito], target=[help him so that he will succeed], predicted=[make to do to succeed success]
# src=[la profecia se hizo realidad], target=[the prophecy came true], predicted=[the prophecy prophecy to to]
# src=[quieres ir al baile conmigo lo siento mucho pero no puedo], target=[do you want to go to the dance with me really sorry but i], predicted=[i want want to to to to to like like like i i]
# src=[cualquier reloj valdra en tanto que sea barato], target=[any watch will do as long as it is cheap], predicted=[watch watch watch so so so]
# src=[reservate para otro rato], target=[save your strength], predicted=[we for for for time]
# src=[tom fue a boston con mary], target=[tom went with mary to boston], predicted=[tom went to with with mary]
# src=[tom esta concentrado], target=[tom is focused], predicted=[tom is]
# src=[por que sigues dandole dinero], target=[why do you keep giving him money], predicted=[why are you get the money]
# src=[parece probable], target=[it seems likely], predicted=[it seems to]
# src=[si me hubiera dado cuenta de lo que tramabas no lo habria concedido], target=[had i realized what you intended i have agreed], predicted=[i you what that had i i i had]
# src=[podes nadar como tom], target=[can you swim like tom], predicted=[can can swim swim tom]
# src=[tom esta cantando], target=[tom is singing], predicted=[singing singing]
# src=[pelea como hombre], target=[fight like a man], predicted=[let break a]
# src=[que te gustaria hacer hoy], target=[what would you like to do today], predicted=[what do you like to do today today]
# src=[la caja era tan pesada que no la pude levantar], target=[the box was so heavy that i lift it], predicted=[the box was so so as i carry carry]
# src=[tom me dio algunos consejos], target=[tom gave me some advice], predicted=[tom gave me some]
# src=[no quiero ir a ningun lado], target=[i want to go any place], predicted=[i want to go anywhere anywhere]
# src=[tom es un mentiroso patologico], target=[tom is a pathological liar], predicted=[tom is a liar liar]
# src=[podemos hablar mas tarde], target=[can we talk later], predicted=[we can talk]
# src=[yo pienso que ella sabe la verdad], target=[i think that she knows the truth], predicted=[i remember the is is]
# src=[tom no necesita trabajar hoy], target=[tom need to go to work today], predicted=[tom need to work]
# src=[no aceptes tragos de extranos], target=[accept drinks from strangers], predicted=[not no no]
# src=[recibio orden de incorporarse en su batallon], target=[he got orders to join his battalion], predicted=[we carried up by to up your]
# src=[todas estas reuniones son en ingles], target=[all of these meetings are in english], predicted=[all english are english english english]
# src=[el no es un santo], target=[no saint], predicted=[he a like]
# src=[cuando juega tenis], target=[when do you play tennis], predicted=[when did play tennis tennis]
# src=[yo la hice mi secretaria], target=[i made her my secretary], predicted=[i made my car]
# src=[el es identico a su hermano mayor], target=[he looks exactly like his older brother], predicted=[he looks like to his brother]
# src=[de vez en cuando estamos de acuerdo], target=[we agree from time to time], predicted=[we of we we we]
# src=[deberias llevarte un paraguas hoy], target=[you had better take an umbrella with you today], predicted=[you should keep a umbrella today]
# src=[tom piensa que mary bebe demasiado cafe], target=[tom thinks that mary drinks too much coffee], predicted=[tom thinks mary mary too much much much]
# src=[tom no conocia que mary podia hablar frances], target=[tom know that mary knew how to speak french], predicted=[tom know mary mary could speak]
# src=[cuando plantaste estos arboles], target=[when did you plant these trees], predicted=[when are you trees trees]
# src=[paso mucho tiempo con tom], target=[i spent a lot of time with tom], predicted=[spend spend long time time tom tom]
# src=[no me arrepiento de lo que hice], target=[i regret what i did], predicted=[i regret what what did did]
# src=[yo fumaba cuando era joven], target=[i smoked when i was young], predicted=[i was when when when was]
# src=[tom busco su botiquin de primeros auxilios pero no lo pudo encontrar], target=[tom looked for his kit but find it], predicted=[tom was his but but but but but but he]
# src=[ya no tomo leche con azucar], target=[i drink milk with sugar any more], predicted=[he drinking no drinking drinking]
# src=[tom no tiene enemigos], target=[tom has no enemies], predicted=[tom have any]
# src=[a quien esta buscando tom], target=[tom looking for], predicted=[who is tom looking for]
# src=[esta suficientemente bien como para trabajar], target=[she is now well enough to work], predicted=[it can well to to]
# src=[esta cancion me recuerda mi infancia], target=[that song reminds me of my childhood], predicted=[this reminds reminds my my my]
# src=[tom y mary jugaron a la ruleta rusa], target=[tom and mary played a game of russian roulette], predicted=[tom and mary were to]
# src=[tom conoce el secreto], target=[tom knows the secret], predicted=[tom knows the secret]
# src=[muchos camioneros comen aca], target=[a lot of truck drivers eat here], predicted=[many many have here here]
# src=[le aconsejo que tomara mas leche], target=[she advised him to drink more milk], predicted=[she advised advised to to to more more more]
# src=[cuando los vio por primera vez], target=[when did you see them first], predicted=[when did you first first first first time]
# src=[alguien esta cantando], target=[singing], predicted=[is singing]
# src=[quienes son esas personas], target=[who are those people], predicted=[who are those those]
# src=[que quieres comprarle a ella], target=[what do you want to buy for her], predicted=[what do you want to to to to]
# src=[ponte tus zapatos], target=[put on your shoes], predicted=[put your your shoes]
# src=[que me aconseja usted hacer], target=[what would you advise me to do], predicted=[what do you you to to to]
# src=[tom era el unico que confiaba en maria], target=[tom was the only one who trusted mary], predicted=[tom only only only only mary mary]
# src=[cuanto cuesta esta pluma], target=[what does this pen cost], predicted=[how much is is is cost]
# src=[tom se tino el pelo castano oscuro], target=[tom dyed his hair dark brown], predicted=[tom has brown hair hair hair]
# src=[que dijiste], target=[what did you say], predicted=[what did you say]
# src=[mi madre y yo estabamos en el jardin], target=[mother and i were in the garden], predicted=[my mother and i in in garden]
# src=[esta bien mientras nadie se entere de eso], target=[okay as long as no one finds out about it], predicted=[it of as when of of]
# src=[me encontre con tom de camino a la escuela], target=[i met tom on my way to school], predicted=[i met tom to way way]
# src=[el doctor me aconsejo dejar de fumar], target=[the doctor advised me to stop smoking], predicted=[the doctor advised me to give smoking smoking]
# src=[ella tiene flores en la mano], target=[she has flowers in her hand], predicted=[she has a in in her]
# src=[donde voy despues de recoger mi equipaje], target=[where do i go after i pick up my baggage], predicted=[when you you to my my my my]
# src=[las he visto antes], target=[seen them before], predicted=[i seen before]
# src=[todo va a ir bien], target=[all going to be ok], predicted=[everything will be]
# src=[tom no desayuna], target=[tom eat breakfast], predicted=[tom eat breakfast]
# src=[ella se divorcio de el luego de muchos anos de miseria], target=[she divorced him after many years of unhappiness], predicted=[she became the of of became became]
# src=[tom y tres de sus amigos se fueron de picnic], target=[tom and three of his friends went on a picnic], predicted=[tom became his three and and a a a]
# src=[se nego a hablar ingles], target=[she refused to speak english], predicted=[he was to speak english]
# src=[ella tenia miedo del perro], target=[she was afraid of the dog], predicted=[she was afraid of dog]
# src=[tengo que decirselo a tom], target=[i must tell tom], predicted=[i have to tell tom]
# src=[tuvimos unas vacaciones maravillosas], target=[we had a wonderful holiday], predicted=[we had a vacation vacation]
# src=[se que aun culpas a tom por la muerte de maria], target=[i know you still blame tom for death], predicted=[i know tom tom tom after after death]
# src=[la vida es divertida], target=[life is fun], predicted=[life is enjoyable]
# src=[el se restablecio poco a poco], target=[he recovered little by little], predicted=[he little little little little little]
# src=[gracias por escuchar], target=[thank you for listening], predicted=[thank you to thank]
# src=[tienes toda la razon], target=[you are completely right], predicted=[you right right]
# src=[creo que deberiamos hacerlo hoy], target=[i think we should do it today], predicted=[i think we should should do]
# src=[estas aburrido], target=[are you bored], predicted=[boring boring]
# src=[tu sientes que los cumpleanos son importantes], target=[do you feel birthdays are important], predicted=[you you your most most]
# src=[lo lamento algo salio mal], target=[sorry something went wrong], predicted=[sorry wrong wrong bad wrong]
# src=[se dice que el ya nunca volvera], target=[they say that he will never return], predicted=[he never never has has will]
# src=[quisiera que pararas de hacer eso], target=[i wish quit doing that], predicted=[like to stop to that]
# src=[hay algunas canciones de escocia], target=[there are some songs from scotland], predicted=[there is a of]
# src=[tenemos mas manzanas de las que podriamos comer en un dia], target=[we have more apples than we could eat in a day], predicted=[we have some apples we we we we we day day day]
# src=[creo que deberias decirle eso a tom], target=[i think you should tell tom that], predicted=[i think you should should that that that]
# src=[lo escuche tatarear en la ducha], target=[i heard him humming in the shower], predicted=[i heard him him in the the]
# src=[me quede sobrecogido ante el espectaculo], target=[i was appalled at the sight], predicted=[i ran shopping to the]
# src=[hice muchos amigos], target=[made lots of friends], predicted=[i made many friends friends]
# src=[parece que a ella le resulta dificil llevarse bien con los estudiantes en la escuela nueva], target=[it seems to be difficult for her to get along with students in the new school], predicted=[it seems to to to to to to to to fun of of of of the the]
# src=[aqui no vive nadie], target=[nobody lives here], predicted=[nobody lives lives]
# src=[eso es lo que la gente no entiende], target=[what people understand], predicted=[people people people]
# src=[no creo que ella este de vuelta para las cinco], target=[i think she will come back by five], predicted=[i think that is is for five five five]
# src=[tu telefono celular sono hace un minuto], target=[your cell phone rang a minute ago], predicted=[phone phone phone phone a minute]
# src=[comprendo que lo arruine], target=[i realize i messed up], predicted=[i think that to the]
# src=[eso ayudo], target=[that helped], predicted=[that that helped]
# src=[como no sabia que decir permanecio callado], target=[not knowing what to say he remained silent], predicted=[how know you know i were die]
# src=[en la oficina tiene lugar una fiesta de despedida], target=[the office is having a farewell party], predicted=[the the first an an an an]
# src=[ella parecia como si me hubiera visto de alguna parte antes], target=[she looked as though she had seen me somewhere before], predicted=[she seemed to to i i i be]
# src=[yo quiero algo dulce de comer], target=[i want something sweet to eat], predicted=[i want to sweet to eat]
# src=[tambien habla frances], target=[he also speaks french], predicted=[speak speaks speak]
# src=[me imagine eso], target=[i imagined that], predicted=[i am that that]
# src=[hable mas alto por favor], target=[could you speak a little louder please], predicted=[please louder louder louder]
# src=[tom se inclino y recogio la moneda], target=[tom leaned over and picked the coin up], predicted=[tom picked down down up up the]
# src=[ella es la chica de mis suenos], target=[she is my dream girl], predicted=[she is the of dreams dreams]
# src=[estaba a punto de salir de mi casa], target=[i was about to leave my house], predicted=[i was to to to my my house]
# src=[he llegado al limite de mi capacidad], target=[reached the limits of my ability], predicted=[been took the the the way way]
# src=[no quiero comer en este restaurante nunca mas], target=[i never want to eat at this restaurant again], predicted=[i want to eat this restaurant restaurant]
# src=[conoci a una anciana], target=[i met an old woman], predicted=[i was her old woman woman]
# src=[la vida empieza cuando te das cuenta de quien eres realmente], target=[life begins when we realize who we really are], predicted=[the your you you you you you]
# src=[lamento que no hayas podido venir con nosotros], target=[sorry that you come with us], predicted=[i that that you help help with with]
# src=[quiero irme de boston], target=[i want to leave boston], predicted=[i want to leave to boston]
# src=[hemos discutido esto], target=[discussed this], predicted=[we this]
# src=[el volvio a casa tras haber estado fuera durante diez meses], target=[he returned home after being away for ten months], predicted=[he came home home ten ten ten ten]
# src=[que hiciste en la escuela hoy], target=[what did you do at school today], predicted=[what did you do at school]
# src=[tienes que lavarte las manos], target=[you need to wash your hands], predicted=[you must wash wash hands hands]
# src=[tenemos solo un par de preguntas mas], target=[we have just a few more questions], predicted=[we have have a few of questions]
# src=[yo engane a tom], target=[i misled tom], predicted=[i understood tom]
# src=[quiero comer helado], target=[i want to eat ice cream], predicted=[i want to eat ice ice]
# src=[los atomos estan compuestos de protones neutrones y electrones], target=[atoms are composed of protons neutrons and electrons], predicted=[they are and and and and and]
# src=[es posible que tom sepa hablar frances], target=[tom might be able to speak french], predicted=[i is tom possible can can can]
# src=[tom bano a su perro], target=[tom gave his dog a bath], predicted=[tom broke his his]
# src=[la economia entro en recesion], target=[the economy has entered a recession], predicted=[the starts starts the]
# src=[estas esperando el bus], target=[are you waiting for the bus], predicted=[are you for the]
# src=[tom se arrepiente de la decision que hizo anoche], target=[tom regrets the decision he made late last night], predicted=[tom made made news test last last last]
# src=[no me gustan los huevos de pascua], target=[i like easter eggs], predicted=[i like eggs]
# src=[estoy segura de que lo lograras], target=[sure that you will succeed], predicted=[sure that will will succeed]
# src=[me alegre mucho de recibir un regalo de ella], target=[i was very glad to get a present from her], predicted=[i am a surprised for her her]
# src=[el no se desalentara con facilidad porque es un tipo duro], target=[he be easily discouraged because a tough guy], predicted=[he understand not of because he he very very]
# src=[que te pareceria una taza de te u otra cosa si es que no estas apurado], target=[how about a cup of tea or something if you in a hurry], predicted=[what a you a a a you you you you a]
# src=[se puede fumar en esta habitacion], target=[you can smoke in this room], predicted=[he can smoking smoking in this room]
# src=[quienes son ellos], target=[who are they], predicted=[who are they]
# src=[puedo trabajar a tiempo parcial], target=[could i work], predicted=[i i work a]
# src=[no fui honesto], target=[i honest], predicted=[i honest honest]
# src=[tom planea vivir en boston durante mas de un ano], target=[tom plans to live in boston for more than a year], predicted=[tom is to go a a a a a a]
# src=[toma bebete esto], target=[here drink this], predicted=[take this this]
# src=[tom no haria algo asi], target=[tom have done something like that], predicted=[tom like like like like]
# src=[he oido eso de mucha gente], target=[heard that from a lot of people], predicted=[i heard of of people people]
# src=[necesito agua], target=[i need water], predicted=[i need water]
# src=[tom lucho], target=[tom fought], predicted=[tom youthful]
# src=[estos boligrafos son mejores que aquellos], target=[these pens are better than those], predicted=[these are are are than than than]
# src=[estoy ayudando], target=[helping out], predicted=[helping]
# src=[me alegra que hayas pasado a verme], target=[glad you dropped by], predicted=[glad you see me see]
# src=[mantente lejos de los taxis sin licencia], target=[keep away from the unlicensed taxis], predicted=[without without without without without without]
# src=[podria matarlas], target=[i could kill you], predicted=[i could kill you]
# src=[lava todo], target=[wash everything], predicted=[wash everything]
# src=[me encanta la musica rock], target=[i love rock music], predicted=[i love music rock]
# src=[nada es imposible], target=[nothing is impossible], predicted=[nothing is]
# src=[el es un experto en astronomia], target=[he is an expert in astronomy], predicted=[he is an expert expert]
# src=[el dinero fue repartido entre los tres], target=[the money was divided among the three], predicted=[the was among among among three]
# src=[cuando voy a cobrar], target=[when do i get paid], predicted=[when will back back to]
# src=[esto parece una trampa], target=[this looks like a trap], predicted=[this looks like a]
# src=[di por supuesto que te unirias a nosotros], target=[i took it for granted that you would join us], predicted=[i took the granted granted granted i you you us]
# src=[supongo que no tengo nada que perder], target=[i guess i have nothing to lose], predicted=[i regret i i have to]
# src=[eso suena razonable], target=[that sounds reasonable], predicted=[that sounds]
# src=[este libro me lo presto un amigo], target=[a friend loaned this book to me], predicted=[this book lent me to a friend]
# src=[quiero lucir distinto], target=[i want to look different], predicted=[i want to else]
# src=[la casa esta embrujada], target=[the house is haunted], predicted=[the house is]
# src=[yo oi a la chica gritar por ayuda], target=[i heard the girl crying for help], predicted=[i heard the girl girl for]
# src=[hay algo que te moleste tom], target=[is something bothering you tom], predicted=[is something for you you]
# src=[marie estudia siempre dos horas al dia], target=[mary always studies for two hours a day], predicted=[tom has always french hours hours hours hours hours]
# src=[tom volvio a su oficina], target=[tom went back to his office], predicted=[tom came back his office]
# src=[quiero irme a casa a dormir], target=[i want to go home and sleep], predicted=[i want to go home home sleep sleep]
# src=[tom se caso con una canadiense], target=[tom married a canadian], predicted=[tom married a a canadian]
# src=[las mujeres trabajaban en casa], target=[women worked at home], predicted=[the they are home]
# src=[no es vuestro problema], target=[not your problem], predicted=[not your problem]
# src=[en africa no ha llovido en absoluto desde hace mas de un mes], target=[they have had no rain in africa for more than a month], predicted=[the has been been in in in of of]
# src=[cual es su nacionalidad], target=[what is his nationality], predicted=[what is]
# src=[estas seguro que no quieres otra soda], target=[are you sure you want another soda], predicted=[are you sure that love love]
# src=[al principio no sabia tocar guitarra], target=[at first i play the guitar], predicted=[i i not i play play the]
# src=[cuidate por favor], target=[please take care of yourself], predicted=[take care care care]
# src=[ellos son bastante importantes], target=[rather important], predicted=[they are very important]
# src=[si yo fuese vos me quedaria fuera de eso], target=[if i were you stay away from that], predicted=[if were i i were i of of of]
# src=[tambien es bella], target=[also a beauty], predicted=[pretty beautiful]
# src=[tenemos razon], target=[right], predicted=[we]
# src=[tom compro un telefono reacondicionado], target=[tom bought a refurbished phone], predicted=[tom bought a refurbished phone]
# src=[y si me niego], target=[what if i refuse], predicted=[if i i]
# src=[la vida de ella esta en peligro], target=[her life is in danger], predicted=[life is in danger danger]
# src=[aun no se hablar frances], target=[i still speak french], predicted=[i know speak french]
# src=[vere a tom por ahi], target=[see tom around], predicted=[see see tom for]
# src=[mi padre se hizo viejo], target=[my father grew old], predicted=[my father was]
# src=[debemos prestar atencion a los problemas medioambientales], target=[we must pay attention to environmental problems], predicted=[we must to more trouble trouble trouble]
# src=[hazlo lo mejor que puedas y no te preocupes], target=[do your best and worry], predicted=[you it better it it it it]
# src=[estoy escuchando una cancion], target=[i am listening to a song], predicted=[i listening listening song song]
# src=[mis piernas me estan matando], target=[my legs are killing me], predicted=[my my are me me]
# src=[puedes arrendar un bote por horas], target=[you can rent a boat by the hour], predicted=[can can can a a for a]
# src=[tom ayudo a mary con su tarea], target=[tom helped mary with her homework], predicted=[tom helped mary with mary homework]
# src=[el frances es una lengua muy interesante], target=[french is a very interesting language], predicted=[he is very very very language]
# src=[cuantos suicidios crees que ocurren al ano en japon], target=[how many suicides do you think there are every year in japan], predicted=[how many do you think think japan japan japan japan]
# src=[cerramos temprano], target=[we closed early], predicted=[get early early]
# src=[necesitamos menos palabras y mas acciones], target=[we need less talk and more action], predicted=[we need more more more more more]
# src=[les invite a la fiesta], target=[i invited them to the party], predicted=[i invited invited invited the party]
# src=[no me di cuenta de que estabas despierto], target=[i realize you were awake], predicted=[i noticed that were were awake]
# src=[ella no dejaba que el fracaso la desalentara], target=[she did not let failure discourage her], predicted=[she urged that that he the]
# src=[el ladron huyo y el policia fue tras el], target=[the thief ran away and the policeman ran after him], predicted=[the thief ran the the and got to caught]
# src=[a ella le gusta escuchar musica], target=[she likes to listen to music], predicted=[she likes to to to music music]
# src=[ella no esperaba que el iba a volver a casa cuando todo hubiese terminado], target=[she have expected that he would come home when everything was over], predicted=[she expected to to home home home that he he home home]
# src=[esta pensando en el problema], target=[he is thinking about the problem], predicted=[is about about the the]
# src=[tiene barba], target=[he has a beard], predicted=[she has a a]
# src=[que hora es en boston], target=[what time is it in boston], predicted=[what time is it in]
# src=[hay algun lugar que recomiendes], target=[is there any place you recommend], predicted=[there there any any than]
# src=[tom queria ir a boston con nosotros], target=[tom wanted to go to boston with us], predicted=[tom wanted to go with with with with]
# src=[tom no tiene ganas de comer], target=[tom feel like eating], predicted=[tom feel like eating]
# src=[mi padre es profesor de ingles], target=[my father is a teacher of english], predicted=[my is is a teacher teacher]
# src=[que hacen ellos], target=[what do they do], predicted=[what did they they]
# src=[tom tan solo no sabe que hacer], target=[tom just know what to do], predicted=[tom only no only what to]
# src=[tom tiene algo importante que decir], target=[tom has something important to say], predicted=[tom has something important to say say]
# src=[tom parece estar ganando], target=[tom appears to be winning], predicted=[tom seems be be]
# src=[el ignoraba el hecho], target=[he was ignorant of the fact], predicted=[he made the]
# src=[hay una manzana sobre el escritorio], target=[there is an apple on the table], predicted=[there is a apple on the desk]
# src=[yo ni se bailar], target=[i even know how to dance], predicted=[i will going]
# src=[es un procedimiento de rutina], target=[routine procedure], predicted=[he is a of of habit]
# src=[encontraron una misteriosa ciudad en ruinas en el desierto], target=[they found a mysterious city in ruins in the desert], predicted=[we were a silence in in in in scenery]
# src=[los nativos se estan poniendo intranquilos], target=[the natives are getting restless], predicted=[the are are high]
# src=[que podria salir mal], target=[what could go wrong], predicted=[what could i be out]
# src=[creo que es mejor no intentarlo], target=[i think better not to try it], predicted=[i think it better try it]
# src=[no necesariamente es asi], target=[it is not necessarily so], predicted=[it know it]
# src=[el viene aqui dos veces por semana], target=[he comes here twice a week], predicted=[he here here here here week]
# src=[sabia que pasaria algo asi], target=[i knew something like this was going to happen], predicted=[i knew that would would happen]
# src=[cuando el era joven veia a menudo el beisbol], target=[when he was young he would often watch baseball], predicted=[when he he he he were very cold]
# src=[un gran numero de ciudadanos ingresaron al ejercito], target=[a great number of citizens went into the army], predicted=[a of of of of to the the]
# src=[tom dio un punetazo a mary], target=[tom slugged mary], predicted=[tom held mary]
# src=[el sobrevivio al impacto de un rayo], target=[he survived being struck by lightning], predicted=[the president attacked an fiercely]
# src=[los mejores peluqueros son gay], target=[the best hairdressers are gay], predicted=[the the are remarkable]
# src=[cualquiera puede hacerlo], target=[anyone can do it], predicted=[anybody can do it]
# src=[a tom le leyeron la palma], target=[tom had his palm read], predicted=[tom tom the the the]
# src=[era tan simple], target=[it was so simple], predicted=[it was so]
# src=[tom le dio un beso tierno a mary], target=[tom gave mary a tender kiss], predicted=[tom gave gave mary kiss mary]
# src=[yo me senti asustado], target=[i felt scared], predicted=[i felt interested]
# src=[llamame de vez en cuando], target=[call me now and then], predicted=[call me at while while]
# src=[te importaria mostrar a tom la ciudad], target=[would you mind showing tom around the city], predicted=[would you like to the the]
# src=[el tiene que lidiar con los reclamos], target=[he has to deal with complaints], predicted=[he has to to to the the]
# src=[tengo trece anos], target=[thirteen], predicted=[i have thirteen]
# src=[tom salio segundo en la carrera], target=[tom came in second in the race], predicted=[tom was on in the the the]
# src=[hay pocos hombres que no lo sepan], target=[there are few men who know that], predicted=[there are than are know]
# src=[me gustaria estar solo ahora], target=[like to be alone now], predicted=[like be be to now now]
# src=[tom hizo un discurso en frances], target=[tom gave a speech in french], predicted=[tom made a a speech]
# src=[ella escribio muchos poemas], target=[she wrote a lot of poems], predicted=[she used a poems poems poems]
# src=[el cristianismo y el islam son dos religiones diferentes], target=[christianity and islam are two different religions], predicted=[he and two are are are are different different]
# src=[era un hombre honesto], target=[he was an honest man], predicted=[he was a honest man]
# src=[me fui a casa], target=[i went home], predicted=[i went to]
# src=[siempre me pongo el casco cuando me monto en la bici], target=[i always wear a helmet when i ride my bicycle], predicted=[i always the how when the the ride the the]
# src=[tienes que ser mas respetuoso], target=[you must be more polite], predicted=[you must be more more]
# src=[la noticia le rompio el corazon], target=[the news broke her heart], predicted=[the news passed the his]
# src=[han transcurrido tres anos desde entonces], target=[three years have passed since then], predicted=[they three been three since since]
# src=[presione el boton por favor], target=[push the button please], predicted=[please the button]
# src=[cuando empezaste a jugar al golf], target=[when did you begin playing golf], predicted=[when did you play playing games]
# src=[ven alguna vez], target=[come anytime], predicted=[have have sometime]
# src=[todo lo que tom queria era un buen bano caliente], target=[all tom wanted was a nice hot bath], predicted=[all tom tom was was was good]
# src=[me secuestraron], target=[they kidnapped me], predicted=[it was worn]
# src=[la lista es ilimitada], target=[the list is limitless], predicted=[the is]
# src=[el fregadero esta lleno de platos sucios], target=[the sink is full of dirty dishes], predicted=[the sink is full of of]
# src=[no puedo llegar alli en una hora], target=[i get there in an hour], predicted=[i talk there an an hour]
# src=[ella vendra incluso si le dices que no lo haga], target=[come even if you tell her not to], predicted=[she will him if she she will him]
# src=[tom se olvido de hacer su tarea], target=[tom forgot to do his homework], predicted=[tom forgot to his his homework]
# src=[yo soy tu padre], target=[your father], predicted=[your father father]
# src=[todos estabamos en silencio], target=[all of us were silent], predicted=[we were were]
# src=[cuando volveras], target=[when will you come back], predicted=[when you you come back]
# src=[todos cambiamos], target=[we all change], predicted=[everyone]
# src=[por que compre flores es eso lo que tu dijiste esta verdaderamente ruidoso aqui asi que no te oi muy bien], target=[why did i buy flowers is that what you just said really noisy here so i hear you very well], predicted=[why that that that that that that so so so so so so so so]
# src=[he estado despierto la noche casi entera], target=[been awake nearly all the night], predicted=[been been up the the night]
# src=[tiene una cintura muy pequena], target=[she has a small waist], predicted=[he has a small small]
# src=[tom y mary son alcoholicos], target=[tom and mary are drunk], predicted=[tom and mary are are]
# src=[entro en el banco y cambio el dinero], target=[he went to the bank and changed his money], predicted=[he bank into the bank bank into the]
# src=[voy aunque llueva a cantaros], target=[go even if it rains heavily], predicted=[i even if if i will]
# src=[mis padres me dijeron que tenemos que respetar a los mayores], target=[my parents told me we should respect the elderly], predicted=[my parents told me me to to to the]
# src=[ellos me necesitan], target=[they need me], predicted=[they need]
# src=[tom llevo a los ninos al parque], target=[tom took the children to the park], predicted=[tom took the the the the]
# src=[tom estaba sentado en un taburete junto a la estufa], target=[tom was sitting on a stool by the stove], predicted=[tom was sitting a a the the the the the]
# src=[tienes previsto ir al extranjero], target=[do you plan to go overseas], predicted=[do you to to go abroad abroad]
# src=[tom saco el taburete situado bajo mary], target=[tom kicked the stool out from under mary], predicted=[tom took the the of of of mary]
# src=[no hable con tom], target=[i speak with tom], predicted=[i to to tom]
# src=[no entiendo y no estoy acostumbrado a no entender por favor expliquelo una vez mas], target=[i understand and not used to not understanding please explain it once more], predicted=[i sure not not not not not not not not am]
# src=[que vas a hacer con mi foto], target=[what are you going to do with my picture], predicted=[why are you to to with my my]
# src=[que piensas que hara ella], target=[what do you think she is going to do], predicted=[what do you think think think will]
# src=[tom se desplomo sobre el suelo], target=[tom slumped to the floor], predicted=[tom stuck at the the]
# src=[viajar en el tiempo es imposible], target=[time travel is impossible], predicted=[it is to the the weather time time]
# src=[hay una galleta debajo de la mesa], target=[a cookie is under the table], predicted=[a a a table table]
# src=[quien es el propietario de este camion], target=[who owns this truck], predicted=[who is the the of this this]
# src=[no me gusta la primavera], target=[i like spring], predicted=[i like spring spring]
# src=[que tienes en la mano], target=[what do you have in your hand], predicted=[what have you in my]
# src=[no esta calificado para aquel trabajo], target=[he is not qualified for the job], predicted=[that that that that that that]
# src=[esto esta un poco salado], target=[this is a little salty], predicted=[this is is little]
# src=[ya esta bueno que hagan espacio para gente joven], target=[high time to make room for young people], predicted=[it are sure are are are are]
# src=[fijate en esto], target=[look at this], predicted=[look at this]
# src=[era su primer trabajo], target=[it was his first job], predicted=[he was his first first]
# src=[gane otra vez], target=[i won again], predicted=[it happen]
# src=[espero a que vuelva], target=[waiting for him to get back], predicted=[i hope for will]
# src=[la radio estaba enchufada], target=[the radio was plugged in], predicted=[the radio was was]
# src=[con mucha dificultad escape de un bote sumergiendose], target=[i escaped from the sinking boat with difficulty], predicted=[a of of of of of of of]
# src=[el canal de panama conecta el atlantico con el pacifico], target=[the panama canal connects the atlantic with the pacific], predicted=[the the the the the to the the pacific]
# src=[puedo ir alla caminando], target=[i can go there on foot], predicted=[can can go walk a]
# src=[estas son maravillosas], target=[these are wonderful], predicted=[are you lying]
# src=[tom es autonomo], target=[tom is self employed], predicted=[tom is]
# src=[abri la boca], target=[open your mouth], predicted=[i opened mouth]
# src=[eres idiota], target=[are you an idiot], predicted=[you idiot]
# src=[mary saco los huevos uno por uno], target=[mary took out the eggs one by one], predicted=[mary took the the of for the]
# src=[necesito pulsar el boton], target=[i need to press the button], predicted=[i need to push the button button]
# src=[senti mi corazon latir fuertemente], target=[i felt my heart beating violently], predicted=[i felt my heart heart]
# src=[tomas es un amigo personal], target=[tom is a personal friend], predicted=[tom is a friend friend]
# src=[venios], target=[come with us], predicted=[come with with]
# src=[mary no sabe nada de coser o calcetar], target=[mary knows nothing of sewing or knitting], predicted=[mary knows anything or or or]
# src=[manana es el ultimo dia de clase], target=[tomorrow is the last day of school], predicted=[i is the the of day]
# src=[es seguro], target=[is it safe], predicted=[is it]
# src=[perdi la esperanza de recibir el sueldo sin pagar], target=[i gave up on receiving the unpaid salary], predicted=[i heard the the because because without without]
# src=[encontramos al nino durmiendo profundamente], target=[we found the boy fast asleep], predicted=[we found the child was a]
# src=[mucho gusto], target=[nice to meet you], predicted=[a lot like much]
# src=[como de lejos esta el museo], target=[how far is it from here to the museum], predicted=[how far is is this]
# src=[viven alla], target=[they live there], predicted=[they live there]
# src=[has estado alli], target=[have you been there], predicted=[been been]
# src=[todo el mundo quiere vivir una vida feliz], target=[everybody wants to live a happy life], predicted=[everyone wants wanted happy happy happy]
# src=[uno de apostoles de jesus se llamaba pablo], target=[one of jesus disciples was named paul], predicted=[what of of the is is is]
# src=[esta habitacion tiene aire acondicionado], target=[this room is], predicted=[this room is clean]
# src=[soy optimista], target=[optimistic], predicted=[i]
# src=[me gusta viajar en tren], target=[i like to travel by train], predicted=[i like to travel by train]
# src=[no lo he oido], target=[i hear it], predicted=[i heard him]
# src=[por que estudias ingles todos los dias], target=[why do you study english every day], predicted=[why do you study study day day]
# src=[siempre bebo un vaso de leche antes de irme a dormir], target=[i always drink a glass of milk before going to sleep], predicted=[i always a a milk milk milk i i to drinking]
# src=[cuentanos lo que paso por favor], target=[please tell us what happened], predicted=[tell what what happened happened]
# src=[oye tom abreme], target=[hey tom open up], predicted=[hey tom tom up]
# src=[hay un libro en el escritorio no no hay], target=[is there a book in the desk no there], predicted=[there book book book book in desk]
# src=[solo tienes una oportunidad para responder correctamente], target=[you have only one chance to answer correctly], predicted=[just have have a chance chance chance]
# src=[hay muchos sitos para visitar en kioto], target=[there are many places to visit in kyoto], predicted=[there are a to to to to kyoto]
# src=[el policia pito al coche para que parara], target=[the policeman whistled for the car to stop], predicted=[the policeman blew the the car to]
# src=[le traere la cuenta inmediatamente], target=[bring you the bill immediately], predicted=[give the money it it]
# src=[no estare aqui mucho tiempo], target=[i be here long], predicted=[not be here a a]
# src=[tom no se podia acordar de que le habia dicho mary que hiciera], target=[tom remember what mary had told him to do], predicted=[tom remember what what mary told to]
# src=[por cuanto tiempo has estudiado el ingles], target=[how long have you been studying english], predicted=[how long time you english english english]
# src=[ahora lo cacho], target=[now i understand], predicted=[now i get it]
# src=[ya has acabado de desayunar], target=[have you finished breakfast yet], predicted=[have finished finished breakfast]
# src=[tom a menudo llegaba tarde al colegio], target=[tom was often late for school], predicted=[tom often often to school school]
# src=[eso es terrible], target=[terrible], predicted=[terrible]
# src=[no somos los campeones], target=[not the champions], predicted=[not are not]
# src=[esta muy enfermo], target=[he is very sick], predicted=[he is ill]
# src=[a quien sea que venga dile que sali], target=[tell whoever comes that out], predicted=[i am tell to to to come]
# src=[se que es importante para ti], target=[i know important to you], predicted=[i know what important you]
# src=[quiza tom pueda decirnos algo], target=[maybe tom can tell us something], predicted=[maybe tom can can to us us]
# src=[no creo que nadie notara lo que hicimos], target=[i think anyone noticed what we did], predicted=[i think the the what can can can]
# src=[tom compra dos o tres camaras por ano], target=[tom buys two or three cameras every year], predicted=[tom two two twice twice two year]
# src=[tienes una casa], target=[do you have a house], predicted=[do you have a house]
# src=[tom esperaba que la lluvia amainara antes que tuviera que caminar a casa], target=[tom hoped the rain would stop before he had to walk home], predicted=[tom was the the the the time would to to to to]
# src=[los felicito por un trabajo bien hecho], target=[i congratulate you on a job well done], predicted=[he work for a good]
# src=[no sabes lo que te estas perdiendo], target=[you know what missing], predicted=[you know what you you you]
# src=[depende de ti el que tengamos exito o no], target=[it is up to you whether we succeed or not], predicted=[it is not to to to the we we not not not]
# src=[no podeis culparle], target=[you blame him], predicted=[you blame him]
# src=[quiero oirlo todo sobre tu viaje a boston], target=[i want to hear all about your trip to boston], predicted=[i want to to to to to to to your]
# src=[tom le dijo adios a mary], target=[tom said goodbye to mary], predicted=[tom told mary goodbye]
# src=[tom intento resolver el problema], target=[tom tried solving the problem], predicted=[tom tried to solve the problem]
# src=[aunque ha estado en el hospital el mantuvo el ritmo de los demas estudiantes], target=[though he had been in the hospital he kept up with other students], predicted=[if he was to to the the the the the the the the the]
# src=[me robaron el monedero en el probador], target=[i had my purse stolen in the changing room], predicted=[my was my stolen stolen stolen stolen stolen]
# src=[pense que ibas a hablar con tom], target=[i thought you were going to talk with tom], predicted=[i thought you were to to to with tom tom]
# src=[cuando es tu fiesta escolar], target=[when is your school festival], predicted=[when is your your]
# src=[tom esta fascinado], target=[tom is fascinated], predicted=[tom is unstoppable]
# src=[esto no es azucar], target=[this sugar], predicted=[this is not]
# src=[yo no puedo tolerar un insulto asi], target=[i put up with an insult like this], predicted=[i cannot a a]
# src=[lo unico que quiero es estar solo], target=[all i want is to be left alone], predicted=[only only want want to to to]
# src=[he perdido un arete], target=[i lost an earring], predicted=[i lost an earring]
# src=[juegas al tenis con nosotros], target=[will you play tennis with us], predicted=[do you play with with]
# src=[tom va a la iglesia los domingos a la manana], target=[tom goes to church on sunday morning], predicted=[tom goes to church church sunday]
# src=[hare mi mejor esfuerzo por no molestar tu estudio], target=[do my best not to disturb your studying], predicted=[i my my best not not not not not]
# src=[el estaba visiblemente nervioso], target=[he was visibly nervous], predicted=[he was nervous nervous nervous]
# src=[voy por el camino correcto], target=[am i on the right road], predicted=[going the the the way]
# src=[que te parece este traje], target=[what do you think of this outfit], predicted=[what is you outfit]
# src=[no me involucres], target=[get me involved], predicted=[i get in]
# src=[quiero volver a verlos], target=[i want to see them again], predicted=[i want to see again again again]
# src=[creo que ahora tomas trabaja], target=[i think tom is working now], predicted=[i think tom is working]
# src=[pense que tom estaba exagerando], target=[i thought tom was exaggerating], predicted=[i thought you was safe]
# src=[esa muchacha tiene las facciones muy finas], target=[that girl has very delicate features], predicted=[the girl has very very attractive]
# src=[el esta mintiendo], target=[lying], predicted=[he is lying]
# src=[me gusto], target=[i liked it], predicted=[i i me]
# src=[dejaras de chismorrear], target=[would you stop babbling], predicted=[stop criticizing shorthanded]
# src=[el nivel del mar esta subiendo], target=[the sea level is rising], predicted=[the population is the the world]
# src=[no creo que tom y mary sean hermanos], target=[i think tom and mary are brother and sister], predicted=[i think tom mary and and]
# src=[tom ya ha empezado], target=[tom has already begun], predicted=[tom has has]
# src=[que hizo tom con el dinero], target=[what did tom do with the money], predicted=[what did tom tom with with]
# src=[nadie te culparia por eso], target=[no one would blame you for that], predicted=[no one you blame for that that]
# src=[ayer vi una pelicula estupenda], target=[i watched a great movie yesterday], predicted=[i saw a new yesterday]
# src=[estuve intentando bajar un poco de peso], target=[been trying to lose a little weight], predicted=[someone was just to some some little]
# src=[su clase tuvo una gran audiencia], target=[his lecture had a large audience], predicted=[his family was a of audience]
# src=[tom saco la escoba del armario del vestibulo], target=[tom took the broom out of the hall closet], predicted=[tom took the the the the the the]
# src=[tom le esta tirando el pelo a mary], target=[tom is pulling hair], predicted=[tom is his hair]
# src=[apenas llueve alli], target=[it hardly ever rains there], predicted=[it it raining there]
# src=[prefiero quedarme en casa que ir de pesca], target=[rather stay home than go fishing], predicted=[i prefer rather to go go]
# src=[me preocupo por ellos], target=[worried about them], predicted=[i worry for about]
# src=[a veces mentimos para no herir los sentimientos de otro], target=[sometimes we lie so that we hurt the feelings of others], predicted=[we just just to to to to stop stop]
# src=[cuidaos], target=[take care of yourself], predicted=[get it]
# src=[la comida estaba como para chuparse los dedos], target=[the food was good], predicted=[the was was like to the]
# src=[la valla necesitaba pintura], target=[the fence needed painting], predicted=[the painting painting paint]
# src=[ese perro corre muy rapido], target=[that dog runs very fast], predicted=[that dog is very fast]
# src=[estoy deseando volver a verte], target=[looking forward to seeing you again], predicted=[looking forward to see seeing you]
# src=[me quedare en la piscina un rato mas], target=[going to stay in the pool a little longer], predicted=[staying in a a long]
# src=[donde conseguiste esta lista], target=[where did you get this list], predicted=[where did you you the this]
# src=[sabes nadar], target=[can you swim], predicted=[do you know swimming]
# src=[que no se te olvide nada], target=[forget anything], predicted=[i i i anything]
# src=[tom queria pasar el resto de su vida con mary], target=[tom wanted to spend the rest of his life with mary], predicted=[tom wanted to spend rest rest of of with with]
# src=[un idiota que se cree inteligente es peor que un simple idiota], target=[a fool that considers himself smart is worse than any other fool], predicted=[an an is an an an an is thinks thinks thinks thinks thinks]
# src=[el hace enojar a la gente a menudo], target=[he often makes people angry], predicted=[he often often proud of of]
# src=[tom llorara], target=[cry], predicted=[tom improvised]
# src=[deja de gritar], target=[stop yelling], predicted=[stop stop yelling]
# src=[los indios lucharon con arcos y flechas], target=[the indians fought with bows and arrows], predicted=[they them and the and and them]
# src=[por que estan enfadadas], target=[why are they angry], predicted=[why are you angry angry]
# src=[estas tu preparando esto], target=[are you making this up], predicted=[are you making this]
# src=[un rio divide la ciudad], target=[a river divides the town], predicted=[a river river the river]
# src=[se asusta facilmente], target=[he scares easily], predicted=[they was afraid easily]
# src=[tom no sabe que decir], target=[tom know what to say], predicted=[tom know what say]
# src=[todos parecen sorprendidos y algo confusos], target=[everybody looks surprised and a little confused], predicted=[everyone looked all and and be]
# src=[estaremos de vuelta a las tres y media], target=[we will be back at half past three], predicted=[be will back back three three three]
# src=[el salto por encima de la zanja poco profunda], target=[he leaped over the shallow ditch], predicted=[he jumped himself with of of]
# src=[no se quebro], target=[it break], predicted=[i go]
# ...
# src=[ella vive con el en un departamento pequeno], target=[she lives with him in a small apartment], predicted=[she lives him a a a beauty beauty]
# src=[me dijo que tenia hambre], target=[he told me that he was hungry], predicted=[he told that he was was]
# src=[me acabo de enterar de que tom esta muerto], target=[i just found out tom is dead], predicted=[this just tom tom tom dead]
# src=[ellos la levantaron por sobre sus cabezas], target=[they lifted her above their heads], predicted=[they they they their their their their]
# src=[no abandono], target=[not giving up], predicted=[not know]
# src=[he terminado todo el trabajo por hoy], target=[finished all the work for today], predicted=[i finished finished finished all]
# src=[el se mudo a tokio], target=[he moved to tokyo], predicted=[he moved to tokyo tokyo]
# src=[el se sintio un poco culpable], target=[he felt a little guilty], predicted=[he felt a little]
# src=[soy profesora de ingles], target=[i am a teacher of english], predicted=[a teacher teacher]
# src=[tengo que ir al hospital], target=[i have to go to the hospital], predicted=[i have to go to the hospital]
# src=[espere], target=[i waited], predicted=[wait wait]
# src=[necesito una caja de clavos], target=[i need a box of nails], predicted=[i need a box of]
# src=[no seas mala], target=[be evil], predicted=[be so]
# src=[te va a encantar este libro], target=[going to love this book], predicted=[going to to this this]
# src=[aquel dia el principe se convirtio en rey], target=[the prince became a king that day], predicted=[the the that that that became a a]
# src=[describelo a tomas], target=[describe tom], predicted=[tom tom]
# src=[el amor es mas fuerte que la muerte], target=[love is stronger than death], predicted=[love is love love love death]
# src=[quiere vivir tanto tiempo como pueda], target=[he wants to live as long as he can], predicted=[i wants to to the as as i i]
# src=[que tipo de canciones son populares estos dias], target=[what kind of songs are popular these days], predicted=[what kind of are are are]
# src=[ella tiene una mala reputacion], target=[she has a bad reputation], predicted=[she has a bad reputation]
# src=[se que no es una broma], target=[i know not a joke], predicted=[i know not a joke]
# src=[su hijo se porta bien], target=[his child behaves well], predicted=[his son is angry]
# src=[tom esta fuera en un viaje de negocios], target=[tom is away on a business trip], predicted=[tom is in in business business business]
# src=[ojala tuviera alas para volar y poder ir a rescatarla], target=[if i had wings to fly i would have gone to save her], predicted=[i wish i i the to would would to to to]
# src=[espero verlo], target=[i hope to see you], predicted=[i hope to see it]
# src=[tom esta ocupado preparando sandwiches en la cocina], target=[tom is busy making sandwiches in the kitchen], predicted=[tom has always begging in the kitchen kitchen]
# src=[casi somos como hermanos], target=[almost like brothers], predicted=[almost are like like]
# src=[tom no me dice nada], target=[tom tell me anything], predicted=[tom tell anything anything]
# src=[ella es lo mas parecido que tiene a una familia], target=[the closest thing to family he has], predicted=[she has a that has has a]
# src=[pense que odiabas a tom], target=[i thought you hated tom], predicted=[i thought you tom tom tom]
# src=[este es el mio], target=[this is mine], predicted=[this is mine]
# src=[vine tan rapido como pude], target=[i came as fast as i could], predicted=[i ran as fast as i could]
# src=[ellos son mas emocionales que nosotros], target=[they are more emotional than we], predicted=[they are smarter than]
# src=[no tiene nada de ciencia], target=[nothing to it], predicted=[he has no of]
# src=[tom se sentia muy culpable por lo sucedido], target=[tom felt very guilty about what happened], predicted=[tom felt felt felt about felt]
# src=[tom no dijo una sola palabra], target=[tom say a word], predicted=[tom say a word word]
# src=[quiero saber la verdad], target=[i want to know the truth], predicted=[i want to know the truth]
# src=[ella se esguinzo las dos munecas en la caida], target=[she sprained both of her wrists in the fall], predicted=[she she the the to to to her]
# src=[salgamos a comer un helado], target=[go out for ice cream], predicted=[go go eat ice ice ice ice]
# src=[yo hice lo mejor que pude], target=[i did my best], predicted=[i did the best best]
# src=[a ella le gustaban la poesia y la musica], target=[she liked poetry and music], predicted=[she asked him music music and music]
# src=[tom viene manana], target=[tom will come tomorrow], predicted=[tom is tomorrow tomorrow]
# src=[como hacemos eso], target=[how do we do that], predicted=[how do we do that]
# src=[hay algun liquido u objetos punzantes en tu equipaje], target=[are there any liquids or sharp objects in your luggage], predicted=[there are a any wild in in in]
# src=[mary lo hizo gratis], target=[mary did it for free], predicted=[mary was the for]
# src=[tu peticion es denegada], target=[your request is denied], predicted=[your your is to]
# src=[fuera esta lloviendo], target=[raining outside], predicted=[raining raining raining raining]
# src=[me encantaria verlo], target=[i would love to see it], predicted=[love to see it]
# src=[apartate de tom], target=[back away from tom], predicted=[take off off]
# src=[el objetivo de la educacion no es la riqueza ni el estatus sino la formacion personal], target=[the goal of education is not wealth or status but personal development], predicted=[the is is but but but but but but but is]
# src=[mary insulto al mesero], target=[mary insulted the waiter], predicted=[mary is the waiter]
# src=[no he empezado], target=[i started], predicted=[not like]
# src=[tendras que ir a boston la proxima semana para ver a tom], target=[have to go to boston to meet tom next week], predicted=[have have to to to to to to tom tom tom]
# src=[parece sospechoso], target=[it looks suspicious], predicted=[does looks suspect suspect]
# src=[el se hirio en el partido de ayer], target=[he got hurt in the game yesterday], predicted=[he was to by the yesterday]
# src=[tu crees que cabra aqui], target=[do you think it will fit here], predicted=[do you think like here here]
# src=[no me diga que me relaje], target=[you tell me to relax], predicted=[tell me me relax relax]
# src=[a veces el primer sintoma de una enfermedad cardiovascular es la muerte], target=[sometimes the first symptom of cardiovascular disease is death], predicted=[the first first the the death death death death]
# src=[no la amo], target=[i love her], predicted=[i love him]
# src=[en la habitacion no hay espacio para otra cama], target=[no space in the room for another bed], predicted=[there room room room room room room room]
# src=[ellos iban de la mano], target=[they went hand in hand], predicted=[they rescued hands house]
# src=[ven a mi casa esta tarde], target=[come to my house this afternoon], predicted=[come home house this this this]
# src=[tom supo cuando dejarlo], target=[tom knew when to quit], predicted=[tom knew where to out out]
# src=[fui criada por tom y mary], target=[i was raised by tom and mary], predicted=[i was up and and and mary mary]
# src=[no me entero de nada], target=[i understand anything], predicted=[i expect all of]
# src=[tom se hirio la pierna jugando futbol], target=[tom hurt his leg while playing football], predicted=[tom was playing watch watch leg]
# src=[te has dejado crecer barba alguna vez], target=[have you ever grown a beard], predicted=[you you ever ever a a a a]
# src=[ya he terminado], target=[already done], predicted=[already already]
# src=[fue culpa suya], target=[it was his fault], predicted=[it was your]
# src=[descubri que su casa estaba ardiendo], target=[i found that his house was on fire], predicted=[i thought that that was was was was full]
# src=[debemos irnos], target=[we must go], predicted=[we must to to]
# src=[ambos quieren decir algo], target=[they both want to say something], predicted=[both people want to say]
# src=[marie nos ayudara manana], target=[mary is going to help us tomorrow], predicted=[tom always us to help us]
# src=[se hacian muchas conjeturas sobre lo que iba a ocurrir], target=[there was a great deal of conjecture as to what would happen], predicted=[there was a of of of what what what happen happen]
# src=[nosotros sentimos a la casa sacudirse un poco], target=[we felt the house shake a little], predicted=[we felt the house little little little]
# src=[siempre esta en casa por la tarde], target=[are you always at home in the evening], predicted=[he is always at the the afternoon]
# src=[tom termino de leer ese libro en una noche], target=[tom finished reading that book in one night], predicted=[tom finished reading reading reading reading book]
# src=[aprendi pronto a nadar], target=[i soon learned how to swim], predicted=[i used to how swim swim swim]
# src=[por donde deberiamos comenzar], target=[where shall we begin], predicted=[where we we start start]
# src=[la puerta esta cerrada con llave desde dentro], target=[the door was locked from the inside], predicted=[the door is locked with with]
# src=[creo que me gusta], target=[i kind of like it], predicted=[i think that like]
# src=[el enfrento al peligro valientemente], target=[he was brave in the face of danger], predicted=[he fear to the danger]
# src=[realmente has cambiado], target=[really changed], predicted=[do you changed]
# src=[no puedes estar seguro de eso], target=[you know that for sure], predicted=[you be sure sure that]
# src=[muestrame como hacer eso], target=[show me how to do that], predicted=[show me how do do]
# src=[tom se hizo pasar por canadiense], target=[tom pretended to be canadian], predicted=[tom made to to a]
# src=[escuchas diariamente la radio en tu casa], target=[do you listen to the radio at home every day], predicted=[would you make your your of with your]
# src=[los perros estuvieron ladrando toda la noche], target=[the dogs barked all night], predicted=[the were all all all all night]
# src=[le pidio que se fuera y se llevara todas sus pertenencias], target=[she asked him to leave and take all his belongings], predicted=[he asked him he he to and and her her of]
# src=[odio las espinacas], target=[i hate spinach], predicted=[i hate my]
# src=[tom y mary siempre juegan tenis los sabados por la manana], target=[tom and mary always play tennis on saturday morning], predicted=[tom always always always always playing tennis tennis on]
# src=[esta tom despierto], target=[is tom awake], predicted=[tom awake awake]
# src=[voy con tom], target=[going with tom], predicted=[going to tom]
# src=[compre un par de botas], target=[i bought a pair of boots], predicted=[i bought a pair of boots]
# src=[te queremos], target=[we love you], predicted=[we want you]
# src=[es muy temprano], target=[very early], predicted=[very is early early]
# src=[cordialmente gracias], target=[thank you kindly], predicted=[thank thank thank]
# src=[tom no quiere que salgas lastimada], target=[tom want you to get hurt], predicted=[tom want to to go go out]
# src=[conecte la tele], target=[i plugged in the tv], predicted=[watch tv tv tv]
# src=[en la oficina ha habido mucha actividad esta manana], target=[been a lot of activity around the office this morning], predicted=[in the office are is in this]
# src=[miro para comprar comestibles todas las mananas], target=[i shop for groceries every morning], predicted=[it and me to to to every morning]
# src=[mama se acaba de ir de compras], target=[mother has just gone shopping], predicted=[mom just just shopping shopping]
# src=[es posible que el partido de futbol se suspenda a causa de la lluvia], target=[the football game might be called off on account of rain], predicted=[it is the weather weather will cause of of of]
# src=[estoy muy contento de poder ayudar], target=[so glad i could help], predicted=[i tired happy help help help]
# src=[entra], target=[go on in], predicted=[go in]
# src=[soy fiel a mi esposa], target=[faithful to my wife], predicted=[am my my my]
# src=[todos han dejado de trabajar], target=[everybody has stopped working], predicted=[all finished finished working]
# src=[no sabemos nada acerca de el], target=[we know anything about him], predicted=[we know about about]
# src=[mama me hizo un traje nuevo], target=[mother made me a new suit], predicted=[mother gave me a suit suit]
# src=[nadie dice eso], target=[no one says that], predicted=[nobody one says]
# src=[no tengo ni la menor idea de lo que quieres decir], target=[i the faintest idea what you mean], predicted=[i have the idea idea what want to to]
# src=[el papel fue inventado en china], target=[paper was first invented in china], predicted=[the was was a yen china china]
# src=[cuando fue la ultima vez que recibiste una carta de tom], target=[when was the last time you received a letter from tom], predicted=[when was the last time was a]
# src=[me di cuenta de que me mirabas], target=[i noticed that you were staring at me], predicted=[i gave me me to me]
# src=[un poco de zumo por favor], target=[some juice please], predicted=[some little please]
# src=[preferiria salir que quedarme adentro], target=[rather go out than stay indoors], predicted=[rather rather go to in]
# src=[lamento el desorden], target=[sorry for the mess], predicted=[sorry the trouble]
# src=[encontraste el paraguas que dijiste que habias perdido el otro dia], target=[have you found the umbrella you said you had lost the other day], predicted=[did you the the you you you lost day day]
# src=[planeo dejar boston tan pronto como me sea posible], target=[i plan to leave boston as soon as i can], predicted=[i to to to to to soon as as as]
# src=[la mayoria de la gente no lo haria asi], target=[most people do that that way], predicted=[most people people do do do]
# src=[ella corrio tan rapido como pudo para alcanzar a los demas], target=[she ran as fast as she could to catch up with the others], predicted=[she ran as as as as could to to to the]
# src=[tomas no tenia a quien mas acudir], target=[tom had no one else to turn to], predicted=[tom have no to to to]
# src=[he oido que en alemania la cerveza es mas barata que el agua es cierto], target=[heard that in germany beer is cheaper than water is that true], predicted=[i heard that water water is is is is is]
# src=[trata bien al gato por favor], target=[please treat the cat well], predicted=[please this wrong wrong]
# src=[paremos un minuto], target=[stop a minute], predicted=[stop a minute]
# src=[a el no le gustaba pedir ayuda aunque se estuviera muriendo de hambre], target=[he like to ask for help even if he was starving], predicted=[he like to mother when when he was]
# src=[no se puede sobrevivir sin dinero], target=[you survive without money], predicted=[he cannot not money]
# src=[tom parece estar buscando problemas], target=[tom seems to be looking for trouble], predicted=[tom seems to be be trouble trouble]
# src=[que estas haciendo ahora], target=[what are you doing now], predicted=[what are doing doing doing]
# src=[nos vemos el lunes], target=[see you on monday], predicted=[we you monday monday]
# src=[gracias por bailar conmigo], target=[thank you for dancing with me], predicted=[thank you for for with with]
# src=[jorge habla cuatro lenguas], target=[jorge can speak four languages], predicted=[speak speak four speak languages languages]
# src=[quieres saber lo que creo que esta pasando], target=[do you want to know what i think is going on], predicted=[do you want to know what going going going]
# src=[estamos seguros de su triunfo], target=[we are sure of his success], predicted=[are are about about means]
# src=[su jardin esta lleno de flores muy hermosas durante todo el ano], target=[their garden is full of very beautiful flowers all the year round], predicted=[the of of of very of very of of of of]
# src=[en este edificio no vive nadie], target=[no one lives in this building], predicted=[no one building lives lives lives]
# src=[el salmon pone sus huevos en agua dulce], target=[salmon lay their eggs in fresh water], predicted=[he put the rice coffee cream]

# %% [markdown]
#     We can see that some translations are really good, but others are not as good. We have to consider that even though we are using bidirectional layers, and it took really long to perform 100 epochs in training, the amount of data used is still small. More data would be necessary for the model to perform better.
