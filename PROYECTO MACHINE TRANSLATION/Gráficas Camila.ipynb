# %%
from fit_model_ import *

# %%
def graphIE(historiales):
    h=1
    for historial in historiales:
        v=0
        
        for variante in historial:
            v=v+1
            for x in ['loss']:
                
                plt.plot(variante[x],label=f"Historic {h} vers {v}")
        h=h+1
    plt.legend()
    plt.xlabel("Epoch",fontsize=13)
    plt.ylabel("Loss",fontsize=13)

# %%
historiales1 = []
historiales1.append(load_history("cp_history_1_1.npy"))
historiales1.append(load_history("cp_history_1_2.npy"))
historiales1.append(load_history("cp_history_1_3.npy"))

historiales2 = []
historiales2.append(load_history("cp_history_2_1.npy"))
historiales2.append(load_history("cp_history_2_2.npy"))
historiales2.append(load_history("cp_history_2_3.npy"))

historiales3 = []
historiales3.append(load_history("cp_history_3_1.npy"))
historiales3.append(load_history("cp_history_3_2.npy"))
historiales3.append(load_history("cp_history_3_3.npy"))

# %% [markdown]
# ### Grafica de las arquitecturas con 3 variantes cada 1 → INGLÉS - ESPAÑOL

# %%
historiales=[]
historiales.append(historiales1)
historiales.append(historiales2)
historiales.append(historiales3)

# %%
graphIE(historiales)

# %%
### Modelo 1
historiales=[]
historiales.append(historiales1)
graphIE(historiales)

# %%
### Modelo 2
historiales=[]
historiales.append(historiales2)
graphIE(historiales)

# %%
### Modelo 3
historiales=[]
historiales.append(historiales3)
graphIE(historiales)

# %%
historiales1 = []
historiales1.append(load_history("cp_history_ei_1_1.npy"))
historiales1.append(load_history("cp_history_ei_1_2.npy"))
historiales1.append(load_history("cp_history_ei_1_3.npy"))

historiales2 = []
historiales2.append(load_history("cp_history_ei_2_1.npy"))
historiales2.append(load_history("cp_history_ei_2_2.npy"))
historiales2.append(load_history("cp_history_ei_2_3.npy"))

historiales3 = []
historiales3.append(load_history("cp_history_ei_3_1.npy"))
historiales3.append(load_history("cp_history_ei_3_2.npy"))
historiales3.append(load_history("cp_history_ei_3_3.npy"))

# %% [markdown]
# ### Grafica de las arquitecturas con 3 variantes cada 1 → ESPAÑOL - INGLÉS

# %%
historiales=[]
historiales.append(historiales1)
historiales.append(historiales2)
historiales.append(historiales3)

# %%
graphIE(historiales)

# %%
### Modelo 1
historiales=[]
historiales.append(historiales1)
graphIE(historiales)

# %%
### Modelo 2
historiales=[]
historiales.append(historiales2)
graphIE(historiales)

# %%
### Modelo 3
historiales=[]
historiales.append(historiales3)
graphIE(historiales)
